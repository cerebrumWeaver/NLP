# %%
import os
import sys
import pickle
from collections import namedtuple
from datetime import datetime
import numpy as np
import apache_beam as beam
from apache_beam.transforms import util
import tensorflow as tf
import tensorflow_hub as tf_hub
import annoy
from sklearn.random_projection import _gaussian_random_matrix
import paddlehub as hub

# %%
embed_fn = None

def generate_embeddings(text, model_url, random_projection_matrix=None):
  # Beam will run this function in different processes that need to
  # import hub and load embed_fn (if not previously loaded)
  global embed_fn
  if embed_fn is None:
    embed_fn = tf_hub.load(model_url)
  embedding = embed_fn(text).numpy()
  if random_projection_matrix is not None:
    embedding = embedding.dot(random_projection_matrix)
  return text, embedding

# %%
def to_tf_example(entries):
  examples = []

  text_list, embedding_list = entries
  for i in range(len(text_list)):
    text = text_list[i]
    embedding = embedding_list[i]

    features = {
        'text': tf.train.Feature(
            bytes_list=tf.train.BytesList(value=[text.encode('utf-8')])),
        'embedding': tf.train.Feature(
            float_list=tf.train.FloatList(value=embedding.tolist()))
    }

    example = tf.train.Example(
        features=tf.train.Features(
            feature=features)).SerializeToString(deterministic=True)

    examples.append(example)

  return examples

# %%
# Beam 流水线
def run_hub2emb(args):
  '''Runs the embedding generation pipeline'''

  options = beam.options.pipeline_options.PipelineOptions(**args)
  args = namedtuple("options", args.keys())(*args.values())

  with beam.Pipeline(args.runner, options=options) as pipeline:
    (
        pipeline
#         | 'Read sentences from files' >> beam.io.ReadFromText(
        | '从文件读入句子' >> beam.io.ReadFromText(
            file_pattern=args.data_dir)
        | 'Batch elements' >> util.BatchElements(
            min_batch_size=args.batch_size, max_batch_size=args.batch_size)
        | 'Generate embeddings' >> beam.Map(
            generate_embeddings, args.model_url, args.random_projection_matrix)
        | 'Encode to tf example' >> beam.FlatMap(to_tf_example)
        | 'Write to TFRecords files' >> beam.io.WriteToTFRecord(
            file_path_prefix='{}/emb'.format(args.output_dir),
            file_name_suffix='.tfrecords')
    )

# %%
def generate_random_projection_weights(original_dim, projected_dim):
  random_projection_matrix = None
  random_projection_matrix = _gaussian_random_matrix(
      n_components=projected_dim, n_features=original_dim).T
  print("A Gaussian random weight matrix was creates with shape of {}".format(random_projection_matrix.shape))
  print('Storing random projection matrix to disk...')
  with open('random_projection_matrix', 'wb') as handle:
    pickle.dump(random_projection_matrix, 
                handle, protocol=pickle.HIGHEST_PROTOCOL)

  return random_projection_matrix

# %%
# model_url = 'https://tfhub.dev/google/nnlm-en-dim128/2'
# model_url = "https://tfhub.dev/google/nnlm-zh-dim128/2"
model_url = r'C:\Users\helix\Downloads\nnlm-zh-dim128_2'
projected_dim = 64

# %%
lac = hub.Module(name="lac")    # 加载lac模型，LAC是Lexical Analysis of Chinese的首字母缩写
# Out:
# [2022-07-26 13:46:07,568] [ WARNING] - The _initialize method in HubModule will soon be deprecated, you can use the __init__() to handle the initialization of the object

# %%
# 分词
def lexical(texts):
    results = lac.cut(text=texts, use_gpu=False, batch_size=1, return_tag=True)
    return results

# %%
# 分词后 文本写入
base_path = r'.\hot_news'
time_paths = os.listdir(base_path)
time_paths
titles = []
for path in time_paths:
    file_paths = os.path.join(base_path, path)
    file_names = os.listdir(file_paths)
    for name in file_names:
        titles += [name.split('.csv')[0]]
titles = lexical(titles)
with open('text.txt', 'w', encoding='utf-8') as out_file:
    for title in titles:
        out_file.write(' '.join(title['word']) + '\n')
titles
# Out:
# [{'word': ['16岁', '男孩', '带', '妹妹', '野泳', '溺亡'],
#   'tag': ['m', 'n', 'v', 'n', 'PER', 'v']},
#  {'word': ['18日', '夜间', '起', '9', '省市', '部分', '地区', '有', '大', '暴雨'],
#   'tag': ['TIME', 't', 'v', 'm', 'n', 'n', 'n', 'v', 'a', 'n']},
#  {'word': ['23名', '教师', '被', '送', '东南亚', '读', '博', '？', '官方', '调查'],
#   'tag': ['m', 'n', 'p', 'v', 'LOC', 'v', 'v', 'w', 'n', 'v']},
#  {'word': ['25岁', '男子', '因', '长相', '成熟', '常', '被', '误', '认为', '42岁'],
#   'tag': ['m', 'n', 'p', 'n', 'a', 'd', 'p', 'ad', 'v', 'm']},
#  {'word': ['31', '省份', '昨', '增', '本土', '117', '+', '393例'],
#   'tag': ['m', 'n', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['35岁', '女', '保安', '边', '带', '娃', '边', '考研', '成功', '上岸'],
#   'tag': ['m', 'a', 'n', 'd', 'v', 'n', 'd', 'v', 'ad', 'v']},
#  {'word': ['4S店', '回应', '销售', '与', '客户', '女儿', '发生', '关系'],
#   'tag': ['n', 'v', 'v', 'p', 'n', 'n', 'v', 'n']},
#  {'word': ['9种', '变异', '株', '登陆', '各省', ' ', '值得', '担心', '吗'],
#   'tag': ['m', 'vn', 'n', 'v', 'n', 'w', 'v', 'vn', 'xc']},
#  {'word': ['A股', '三大', '指数', '集体', '收', '涨', ' ', '沪指', '涨', '1.55%'],
#   'tag': ['nz', 'm', 'n', 'n', 'v', 'v', 'w', 'n', 'v', 'm']},
#  {'word': ['WTT', '冠军赛', '马龙', '首秀', '赢球', '晋级'],
#   'tag': ['nt', 'n', 'PER', 'n', 'v', 'v']},
#  {'word': ['WTT', '冠军赛', '：', '陈梦', '伤愈', '复出', '逆转', '晋级'],
#   'tag': ['nz', 'n', 'w', 'PER', 'v', 'vn', 'v', 'v']},
#  {'word': ['“', 'i', '茅台', '”', '公布', '新一轮', '每日', '投放', '时间'],
#   'tag': ['w', 'xc', 'nz', 'w', 'v', 'm', 'TIME', 'vn', 'n']},
#  {'word': ['“',
#    '制',
#    '枪',
#    '村',
#    '”',
#    '的',
#    '二十年',
#    '：',
#    '如何',
#    '走出',
#    '罪',
#    '与',
#    '穷'],
#   'tag': ['w',
#    'v',
#    'n',
#    'n',
#    'w',
#    'u',
#    'TIME',
#    'w',
#    'r',
#    'v',
#    'n',
#    'c',
#    'an']},
#  {'word': ['“', '双', '积分', '”', '新政', '或', '将', '落地'],
#   'tag': ['w', 'm', 'n', 'w', 'n', 'c', 'd', 'v']},
#  {'word': ['《', '人生若如初见', '》', '有', '哪些', '期待', '点'],
#   'tag': ['w', 'nw', 'w', 'v', 'r', 'vn', 'n']},
#  {'word': ['《', '外太空的莫扎特', '》', '票房', '破', '亿'],
#   'tag': ['w', 'nw', 'w', 'n', 'v', 'm']},
#  {'word': ['万元', '电视', '“', '保护膜', '”', '被', '撕', '直接', '变', '白屏'],
#   'tag': ['m', 'n', 'w', 'n', 'w', 'p', 'v', 'ad', 'v', 'n']},
#  {'word': ['万香科技', 'IPO', '被否'], 'tag': ['ORG', 'nz', 'v']},
#  {'word': ['上海', '上半年', 'GDP', '下降', '5.7%'],
#   'tag': ['LOC', 'TIME', 'n', 'v', 'm']},
#  {'word': ['专家', '预测', '下半年', '全球', '物价', '走势'],
#   'tag': ['n', 'v', 'TIME', 'n', 'n', 'n']},
#  {'word': ['世纪佳缘', '回应', 'CEO', '等人', '“', '消失', '”', '传闻'],
#   'tag': ['ORG', 'v', 'n', 'n', 'w', 'v', 'w', 'n']},
#  {'word': ['两', '部门', '联合', '通报', '“', '大棚', '房', '”', '问题'],
#   'tag': ['m', 'n', 'vd', 'v', 'w', 'n', 'n', 'w', 'n']},
#  {'word': ['中俄', '天然气', '管道', '项目', '2024年', '动工'],
#   'tag': ['LOC', 'n', 'n', 'n', 'TIME', 'v']},
#  {'word': ['中信证券', '研究', '团队', '拆解', '特斯拉', '出', '研报'],
#   'tag': ['ORG', 'vn', 'n', 'v', 'PER', 'v', 'n']},
#  {'word': ['中印', '举行', '第16轮', '军长', '级', '会谈'],
#   'tag': ['ns', 'v', 'm', 'n', 'n', 'vn']},
#  {'word': ['中方', '发布', '中', '菲', '基础设施', '合作', '的', '声明'],
#   'tag': ['n', 'v', 'f', 'LOC', 'n', 'vn', 'u', 'n']},
#  {'word': ['乌', '回应', '梅德韦杰夫', '“', '审判日', '警告', '”'],
#   'tag': ['ns', 'v', 'PER', 'w', 'nz', 'v', 'w']},
#  {'word': ['乌媒', '：', '俄军', '开始', '猛烈', '炮击', '尼科波尔市'],
#   'tag': ['n', 'w', 'n', 'v', 'ad', 'v', 'LOC']},
#  {'word': ['乌方', '称', '可能', '攻击', '克里米亚', ' ', '俄方', '回应'],
#   'tag': ['PER', 'v', 'v', 'v', 'LOC', 'w', 'n', 'v']},
#  {'word': ['乌称', '或', '使用', '“', '海马斯', '”', '打击', '俄军', '目标'],
#   'tag': ['n', 'c', 'v', 'w', 'nz', 'w', 'v', 'n', 'n']},
#  {'word': ['习酒集团', '成立', ' ', '注册资本', '37.5亿元'],
#   'tag': ['ORG', 'v', 'w', 'nz', 'm']},
#  {'word': ['云南人大财经委', '原', '主任', '委员', '王长勇', '被查'],
#   'tag': ['ORG', 'a', 'n', 'n', 'PER', 'v']},
#  {'word': ['京涿城际通勤高铁', '试运行'], 'tag': ['nz', 'vn']},
#  {'word': ['什么', '是', '摩擦性失业'], 'tag': ['r', 'v', 'nz']},
#  {'word': ['今夜', '起', '新一轮', '降雨', '过程', '将至'],
#   'tag': ['TIME', 'v', 'm', 'vn', 'n', 'v']},
#  {'word': ['俄方', '首次', '展出', '亚速钢铁厂', '战利品'],
#   'tag': ['LOC', 'm', 'v', 'ORG', 'n']},
#  {'word': ['俄罗斯', '和', '伊朗', '双边', '交易', '将', '放弃', '美元'],
#   'tag': ['LOC', 'c', 'LOC', 'n', 'n', 'd', 'v', 'nz']},
#  {'word': ['俄', '防长', '要求', '俄军', '优先', '摧毁', '乌远程', '导弹'],
#   'tag': ['LOC', 'n', 'v', 'n', 'vd', 'v', 'a', 'n']},
#  {'word': ['全国', 'ATM机', '降至', '百万台', '以下'], 'tag': ['n', 'n', 'v', 'm', 'f']},
#  {'word': ['全国', '多', '地', '将', '遭', '强降雨', '侵袭'],
#   'tag': ['n', 'a', 'u', 'd', 'v', 'n', 'v']},
#  {'word': ['共青团中央', '：', '嘲讽', '小镇', '做题', '家', '是', '病'],
#   'tag': ['ORG', 'w', 'v', 'n', 'v', 'n', 'v', 'n']},
#  {'word': ['养老', '诈骗', '团伙', '骗', '1亿', ' ', '赃款', '深', '埋', '猪圈'],
#   'tag': ['vn', 'vn', 'n', 'v', 'm', 'w', 'n', 'd', 'v', 'n']},
#  {'word': ['内蒙古集宁区住建局', '约谈', '房企'], 'tag': ['ORG', 'v', 'n']},
#  {'word': ['农村', '母女', '高情商', '拌嘴', '吸', '粉', '600万'],
#   'tag': ['n', 'n', 'n', 'v', 'v', 'n', 'm']},
#  {'word': ['凯迪拉克', '回应', '新车', '被曝', '虚假', '宣传'],
#   'tag': ['nz', 'v', 'n', 'v', 'a', 'vn']},
#  {'word': ['刘德华', '代替', '陈木胜', '太太', '读', '获奖', '感言'],
#   'tag': ['PER', 'v', 'PER', 'n', 'v', 'vn', 'n']},
#  {'word': ['刘雅瑟', '金像奖', '第九位', '内地', '影后'],
#   'tag': ['PER', 'nz', 'm', 's', 'n']},
#  {'word': ['前海人寿', '提议', '免职南玻A', '一名', '董事'],
#   'tag': ['ORG', 'v', 'nz', 'm', 'n']},
#  {'word': ['北京', '一', '感染者', '健康', '监测期', '曾', '擅自', '外出'],
#   'tag': ['LOC', 'm', 'n', 'a', 'n', 'd', 'd', 'v']},
#  {'word': ['北京市政协', '原', '副主席', '于鲁明', '被', '双开'],
#   'tag': ['ORG', 'a', 'n', 'PER', 'p', 'v']},
#  {'word': ['北京', '顺义', '一地', '升高', '风险'],
#   'tag': ['LOC', 'LOC', 'n', 'v', 'n']},
#  {'word': ['北京', '顺义', '两地', '出现', '混检', '初筛', '阳性'],
#   'tag': ['LOC', 'LOC', 'n', 'v', 'vn', 'vn', 'n']},
#  {'word': ['北京', '顺义', '新增', '2例', '阳性'],
#   'tag': ['LOC', 'LOC', 'v', 'm', 'n']},
#  {'word': ['北大', '毕业生', '为', '“', '讨', '汤', '奶奶', '”', '之', '子', '募捐'],
#   'tag': ['ORG', 'n', 'v', 'w', 'v', 'n', 'n', 'w', 'u', 'n', 'v']},
#  {'word': ['北海', '：', '绿码', '游客', '凭', '48小时', '核酸', '可', '返程'],
#   'tag': ['LOC', 'w', 'n', 'n', 'p', 'TIME', 'n', 'v', 'v']},
#  {'word': ['北溪', '1', '涡轮机', '已', '从', '加拿大', '空运', '至', '德国'],
#   'tag': ['ns', 'm', 'n', 'd', 'p', 'LOC', 'v', 'v', 'LOC']},
#  {'word': ['午评', '：', '三大', '指数', '震荡', '攀升', ' ', '百股', '涨停'],
#   'tag': ['n', 'w', 'm', 'n', 'vd', 'v', 'w', 'm', 'v']},
#  {'word': ['华为Mate', ' ', '50', '发布', '时间', '曝光'],
#   'tag': ['nz', 'w', 'm', 'v', 'n', 'v']},
#  {'word': ['华为', '鸿蒙', '3.0', '系统', '7月27日', '发布'],
#   'tag': ['ORG', 'n', 'm', 'n', 'TIME', 'v']},
#  {'word': ['南方', '高温', '天气', '将', '“', '卷土重来', '”'],
#   'tag': ['s', 'n', 'n', 'p', 'w', 'v', 'w']},
#  {'word': ['南非', '有', '中国', '公民', '遭', '绑架', '不幸', '遇难'],
#   'tag': ['LOC', 'v', 'LOC', 'n', 'v', 'vn', 'ad', 'v']},
#  {'word': ['原', '中央党校', '副校长', '韩树英', '逝世'],
#   'tag': ['a', 'ORG', 'n', 'PER', 'v']},
#  {'word': ['原', '银监会纪委', '张岩森', '离职', '13年后', '被查'],
#   'tag': ['a', 'ORG', 'PER', 'v', 'TIME', 'v']},
#  {'word': ['台', '专家', '批', '民进党', '挖深', '两岸', '鸿沟'],
#   'tag': ['n', 'n', 'v', 'ORG', 'v', 'n', 'n']},
#  {'word': ['台北', '市长', '选举', '三', '强鼎立'], 'tag': ['LOC', 'n', 'v', 'm', 'an']},
#  {'word': ['台湾', '渔民', '钓', '起', '玳瑁', '石斑', ' ', '称', '50年', '首见'],
#   'tag': ['LOC', 'n', 'v', 'v', 'n', 'n', 'w', 'v', 'TIME', 'v']},
#  {'word': ['各地', '考生', '收到', '清北', '录取通知书', '瞬间'],
#   'tag': ['n', 'n', 'v', 'ns', 'n', 't']},
#  {'word': ['同事', '在', '背后', '说', '我', '坏话', '怎么', '办'],
#   'tag': ['n', 'p', 's', 'v', 'r', 'n', 'r', 'v']},
#  {'word': ['吴费曼', '恭喜', '吴镇', '宇金像奖', '颗粒', '无收'],
#   'tag': ['PER', 'v', 'LOC', 'nz', 'n', 'v']},
#  {'word': ['哈士奇', '被', '蛇咬', '后', '脸', '肿', ' ', '神似', '史努比'],
#   'tag': ['nz', 'p', 'v', 'f', 'n', 'v', 'w', 'a', 'PER']},
#  {'word': ['哈尔滨', '三胎', '家庭', '购', '新房', '补贴', '2万'],
#   'tag': ['LOC', 'm', 'n', 'v', 'n', 'v', 'm']},
#  {'word': ['哈尔滨', '拟', '出台', '购房', '支持', '措施'],
#   'tag': ['LOC', 'v', 'v', 'v', 'vn', 'n']},
#  {'word': ['哈登',
#    '：',
#    '让',
#    '76',
#    '人',
#    '先',
#    '补强',
#    '剩下',
#    '的',
#    '钱',
#    '再',
#    '给',
#    '我'],
#   'tag': ['PER', 'w', 'v', 'm', 'n', 'd', 'v', 'v', 'u', 'n', 'd', 'v', 'r']},
#  {'word': ['商场', '回应', '小鸭子', '换班', '走红', '：', '三班', '倒'],
#   'tag': ['n', 'v', 'n', 'v', 'v', 'w', 'n', 'v']},
#  {'word': ['四川',
#    '1',
#    '死',
#    '7',
#    '伤气',
#    '垫',
#    '泳池',
#    '：',
#    '多',
#    '人',
#    '被',
#    '冲进',
#    '河道'],
#   'tag': ['LOC', 'm', 'v', 'm', 'n', 'v', 'n', 'w', 'a', 'n', 'p', 'v', 'n']},
#  {'word': ['四川', '昨', '增', '本土', '9', '+', '14例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['四川', '气垫', '泳池', '垮塌', ' ', '死者', '高考', '637分'],
#   'tag': ['LOC', 'n', 'n', 'v', 'w', 'n', 'n', 'm']},
#  {'word': ['国资委', '发布', '央企', '负责人', '考核', '结果'],
#   'tag': ['ORG', 'v', 'n', 'n', 'vn', 'n']},
#  {'word': ['复旦大学', '原', '校长', '杨福', '家', '逝世'],
#   'tag': ['ORG', 'a', 'n', 'PER', 'n', 'v']},
#  {'word': ['夏联中国德比', '：', '曾凡', '博', '7分', '张镇麟', '1', '助'],
#   'tag': ['ORG', 'w', 'PER', 'v', 'm', 'PER', 'm', 'v']},
#  {'word': ['外交部', '回应', '“', '美沙', '合作', '开发', '5G', '”'],
#   'tag': ['nt', 'v', 'w', 'nr', 'v', 'v', 'n', 'w']},
#  {'word': ['外交部', '：', '中菲', '合作', '项目', '将', '做大', '做强'],
#   'tag': ['nt', 'w', 'LOC', 'vn', 'n', 'd', 'v', 'v']},
#  {'word': ['外国人', '唱', '中文', '歌', '太', '惊艳', '了'],
#   'tag': ['n', 'v', 'nz', 'n', 'd', 'a', 'xc']},
#  {'word': ['外国', '女子', '患', '新冠后遗症', ' ', '申请', '安乐死'],
#   'tag': ['n', 'n', 'v', 'nz', 'w', 'v', 'n']},
#  {'word': ['多位', '名人', '力挺', '易烊千玺'], 'tag': ['m', 'n', 'v', 'PER']},
#  {'word': ['天津', '4S店', '员工', '疑', '与', '未成年人', '发生', '关系'],
#   'tag': ['LOC', 'n', 'n', 'v', 'p', 'n', 'v', 'n']},
#  {'word': ['天津', '一', '民警', '值班', '时', '突发', '疾病', '因公', '牺牲'],
#   'tag': ['LOC', 'm', 'n', 'v', 'n', 'v', 'n', 'd', 'v']},
#  {'word': ['天津', '今', '增', '2名', '阳性', ' ', '为', '主动', '就医', '发现'],
#   'tag': ['LOC', 't', 'v', 'm', 'n', 'w', 'p', 'ad', 'v', 'v']},
#  {'word': ['央媒', '评为', '防疫', '拆', '住户', '门锁', '：', '离', '大谱'],
#   'tag': ['n', 'v', 'vn', 'v', 'n', 'n', 'w', 'v', 'n']},
#  {'word': ['奇葩', '卖房', '故事', '：', '万斤', '桃', '抵', '18万', '购房', '款'],
#   'tag': ['n', 'vn', 'n', 'w', 'm', 'n', 'v', 'm', 'vn', 'n']},
#  {'word': ['女子', '看', '直播', '二十万', '买', '古董', '到货', '后', '退', '款', '难'],
#   'tag': ['n', 'v', 'vn', 'm', 'v', 'n', 'v', 'f', 'v', 'n', 'a']},
#  {'word': ['女子', '给', '流浪汉', '买', '鞋', '丢', '地上', '被', '指', '粗鲁'],
#   'tag': ['n', 'p', 'n', 'v', 'n', 'v', 's', 'p', 'v', 'a']},
#  {'word': ['女子', '违', '停', '被', '交警', '老公', '贴', '罚单'],
#   'tag': ['n', 'v', 'v', 'p', 'n', 'n', 'v', 'n']},
#  {'word': ['女孩', '被', '后妈', '打', '到', '遍体鳞伤', ' ', '警方', '回应'],
#   'tag': ['n', 'p', 'n', 'v', 'v', 'a', 'w', 'n', 'v']},
#  {'word': ['女孩', '被骗', '3万', '后', '不服气', '又', '被骗', '5万'],
#   'tag': ['n', 'v', 'm', 'f', 'v', 'd', 'v', 'm']},
#  {'word': ['如何', '解读', '易烊千玺', '最新', '回应'],
#   'tag': ['r', 'v', 'PER', 'a', 'vn']},
#  {'word': ['婆婆', '城里', '天天', '睡觉', '回乡', '瞬间', '恢复', '活力'],
#   'tag': ['n', 's', 'q', 'v', 'v', 't', 'v', 'n']},
#  {'word': ['媒体', '评', '防疫', '破锁', '：', '不能', '牺牲', '居民', '安全感'],
#   'tag': ['n', 'v', 'vn', 'n', 'w', 'v', 'v', 'n', 'n']},
#  {'word': ['媒体', '：', '德里赫特', '转会', '拜仁', '交易', '达成'],
#   'tag': ['n', 'w', 'PER', 'v', 'ORG', 'n', 'v']},
#  {'word': ['安倍', '遇', '刺案', '嫌犯', '被曝', '欠债', '60万日元'],
#   'tag': ['PER', 'v', 'n', 'n', 'v', 'v', 'm']},
#  {'word': ['官方', '回应', '护士', '抢救', '病人', '看', '手机'],
#   'tag': ['n', 'v', 'n', 'v', 'n', 'v', 'n']},
#  {'word': ['官方', '通报', '6起', '“', '大棚', '房', '”', '典型', '案例'],
#   'tag': ['n', 'v', 'm', 'w', 'n', 'n', 'w', 'a', 'n']},
#  {'word': ['实探', '四川', '1', '死', '7', '伤泳池', '垮塌', '事故', '现场'],
#   'tag': ['v', 'LOC', 'm', 'v', 'm', 'n', 'v', 'n', 's']},
#  {'word': ['小男孩', '发现', '天文馆', '错误', '百出气', '到', '暴走'],
#   'tag': ['n', 'v', 'n', 'n', 'v', 'v', 'n']},
#  {'word': ['小米', '回应', '被', '意大利', '罚款', '320万欧元'],
#   'tag': ['ORG', 'v', 'p', 'LOC', 'v', 'm']},
#  {'word': ['山西', '两地级市', '公安局长', '履新', '高校', '副职'],
#   'tag': ['LOC', 'LOC', 'n', 'v', 'n', 'n']},
#  {'word': ['工人', '全', '月', '无休', '下班', '猝死', ' ', '公司', '赔', '36万'],
#   'tag': ['n', 'a', 'n', 'v', 'v', 'v', 'w', 'n', 'v', 'm']},
#  {'word': ['开拓者', '官方', '晒', '出', '夏联', '夺冠', '海报'],
#   'tag': ['n', 'n', 'v', 'v', 'n', 'vn', 'n']},
#  {'word': ['张家辉', '称', '关咏荷', '已', '为', '弟弟', '办妥', '后事'],
#   'tag': ['PER', 'v', 'PER', 'd', 'p', 'n', 'v', 'n']},
#  {'word': ['张小泉', '总经理', '称', '中国', '人', '切菜', '方法', '不对'],
#   'tag': ['PER', 'n', 'v', 'LOC', 'n', 'vn', 'n', 'a']},
#  {'word': ['张小泉', '竞争对手', '直播', '拍', '蒜', '一天'],
#   'tag': ['PER', 'n', 'v', 'v', 'n', 'TIME']},
#  {'word': ['张小泉', '竞争对手', '直播', '菜刀', '拍', '蒜', '一整天'],
#   'tag': ['PER', 'n', 'vn', 'n', 'v', 'n', 'm']},
#  {'word': ['张文宏', '团队', '：', '户外', '采样', '无需', '穿', '大白'],
#   'tag': ['PER', 'n', 'w', 's', 'v', 'v', 'v', 'n']},
#  {'word': ['律师', '黄', '码', '无法', '出庭', '被撤诉', '？', '法院', '致歉'],
#   'tag': ['n', 'a', 'n', 'vd', 'v', 'v', 'w', 'n', 'v']},
#  {'word': ['德媒', '谈', '“', '斯里兰卡', '破产', '”'],
#   'tag': ['n', 'v', 'w', 'LOC', 'v', 'w']},
#  {'word': ['意大利女排', '击败', '巴西', '首夺', '世联赛', '冠军'],
#   'tag': ['ORG', 'v', 'LOC', 'v', 'nz', 'n']},
#  {'word': ['成都', '全市', '酒吧', '等', '密闭', '空间', '暂停', '营业'],
#   'tag': ['LOC', 'n', 'n', 'u', 'vn', 'n', 'v', 'vn']},
#  {'word': ['成都', '成华区', '多', '地', '调整', '为', '高中', '风险', '区'],
#   'tag': ['LOC', 'LOC', 'a', 'u', 'v', 'v', 'n', 'n', 'n']},
#  {'word': ['成都', '暂停', '营运', '98条', '道路', '客运', '班线'],
#   'tag': ['LOC', 'v', 'v', 'm', 'n', 'n', 'n']},
#  {'word': ['成都', '本轮', '疫情', '毒株', '国内', '无', '同源', '序列'],
#   'tag': ['LOC', 'r', 'n', 'n', 's', 'v', 'n', 'n']},
#  {'word': ['成都', '本轮', '疫情', '轨迹', '比较', '复杂'],
#   'tag': ['LOC', 'r', 'n', 'n', 'd', 'a']},
#  {'word': ['拜登', '和', '普京', '较量', '中东', ' ', '谁', '会', '赢'],
#   'tag': ['PER', 'c', 'PER', 'v', 'LOC', 'w', 'r', 'v', 'v']},
#  {'word': ['拜登', '赴', '中东', '为何', '还', '拿', '中国', '说事'],
#   'tag': ['PER', 'v', 'LOC', 'r', 'd', 'v', 'LOC', 'n']},
#  {'word': ['教育改革', '会', '影响', '小镇', '做题', '家', '的', '出路', '吗'],
#   'tag': ['vn', 'v', 'v', 'n', 'v', 'n', 'u', 'n', 'xc']},
#  {'word': ['新疆', '多', '个', '不同', '色', '发光体', '划过', '夜空'],
#   'tag': ['LOC', 'a', 'q', 'a', 'n', 'n', 'v', 'n']},
#  {'word': ['新疆', '疑似', '出现', '火流星'], 'tag': ['LOC', 'v', 'v', 'nz']},
#  {'word': ['日本政府', '决定', '保留', '萨哈林', '2号', '股份'],
#   'tag': ['ORG', 'v', 'v', 'PER', 'm', 'n']},
#  {'word': ['日本自卫队', '两架', '直升机', '疑遭', '激光', '照射'],
#   'tag': ['ORG', 'm', 'n', 'v', 'n', 'v']},
#  {'word': ['易烊千玺', '：', '放弃', '入职', '国家', '话剧院'],
#   'tag': ['PER', 'w', 'v', 'v', 'n', 'n']},
#  {'word': ['智库', '外交', '折射', '美国', '各界', '对华', '真实', '态度'],
#   'tag': ['n', 'n', 'v', 'LOC', 'n', 'd', 'a', 'n']},
#  {'word': ['李现', '新剧', '《', '人生若如初见', '》', '定档'],
#   'tag': ['PER', 'n', 'w', 'nw', 'w', 'v']},
#  {'word': ['校方', '回应', '按', '中考', '成绩', '排队', '办', '入学'],
#   'tag': ['n', 'v', 'p', 'n', 'n', 'v', 'v', 'v']},
#  {'word': ['梅艳芳', '出道', '40周年'], 'tag': ['PER', 'v', 'TIME']},
#  {'word': ['梦想', '照', '进', '现实', ' ', '努力', '终', '有', '回报'],
#   'tag': ['n', 'v', 'v', 'n', 'w', 'ad', 'd', 'v', 'vn']},
#  {'word': ['欧洲', '多国', '或', '刷新', '高温', '纪录'],
#   'tag': ['LOC', 'n', 'c', 'v', 'n', 'n']},
#  {'word': ['武契奇', '与', '乌克兰', '议员', '“', '互', '呛', '”'],
#   'tag': ['PER', 'p', 'LOC', 'n', 'w', 'd', 'v', 'w']},
#  {'word': ['民警', '苦劝', '无果', '现场', '写', '代码', '揭', '诈骗'],
#   'tag': ['n', 'v', 'v', 's', 'v', 'n', 'v', 'vn']},
#  {'word': ['沙特', '高官', '：', '我', '反对', '把', '中国', '视为', '敌人'],
#   'tag': ['LOC', 'n', 'w', 'r', 'v', 'p', 'LOC', 'v', 'n']},
#  {'word': ['河北廊坊饭店', '外', '发生', '打架案', ' ', '1', '人', '被拘'],
#   'tag': ['ORG', 'f', 'v', 'n', 'w', 'm', 'n', 'v']},
#  {'word': ['河南', '信阳', '今', '增', '1例', '核酸', '阳性'],
#   'tag': ['LOC', 'LOC', 't', 'v', 'm', 'n', 'n']},
#  {'word': ['泽连斯基', '与', '加拿大', '总理', '特鲁多', '通话'],
#   'tag': ['PER', 'p', 'LOC', 'n', 'PER', 'v']},
#  {'word': ['泽连斯基', '：', '正', '调查', '651起', '官员', '通', '敌案'],
#   'tag': ['PER', 'w', 'd', 'v', 'm', 'n', 'v', 'n']},
#  {'word': ['济南', '90后', '小伙', '辞掉', '银行', '工作', '养', '鸵鸟'],
#   'tag': ['LOC', 'nz', 'n', 'v', 'n', 'n', 'v', 'n']},
#  {'word': ['浙江', '一', '渔船', '被', '吹翻', '已', '致', '7', '人', '死亡'],
#   'tag': ['LOC', 'm', 'n', 'p', 'v', 'd', 'v', 'm', 'n', 'v']},
#  {'word': ['浙江', '一', '渔船', '被', '吹翻', '致', '6', '死', '1', '失联'],
#   'tag': ['LOC', 'm', 'n', 'p', 'v', 'v', 'm', 'v', 'm', 'v']},
#  {'word': ['浙江交警协管员', '执勤', '晒', '出', '渐变色'],
#   'tag': ['ORG', 'v', 'v', 'v', 'n']},
#  {'word': ['浙江', '女子', '将', '婴儿', '扔', '在', '垃圾', '堆', '后', '离开'],
#   'tag': ['LOC', 'n', 'p', 'n', 'v', 'p', 'n', 'v', 'f', 'v']},
#  {'word': ['满舒克', '演出', '现场', '疑', '有人', '猥亵', '女生'],
#   'tag': ['PER', 'v', 's', 'v', 'r', 'v', 'n']},
#  {'word': ['热火篮网', '未', '就', '杜兰特', '交易', '接近达协议'],
#   'tag': ['nz', 'd', 'd', 'PER', 'v', 'nz']},
#  {'word': ['猎豹汽车', '经销商', '深陷', '“', '三角', '债务', '”'],
#   'tag': ['ORG', 'n', 'v', 'w', 'n', 'n', 'w']},
#  {'word': ['王楚钦', '夺得', 'WTT', '球星', '挑战赛', '男单', '冠军'],
#   'tag': ['PER', 'v', 'nz', 'n', 'n', 'n', 'n']},
#  {'word': ['王毅', '同', '匈牙利', '外长', '通', '电话'],
#   'tag': ['PER', 'p', 'LOC', 'n', 'v', 'n']},
#  {'word': ['王老吉', '被', '指', '割', '韭菜', ' ', '加盟商', '亏', '上', '百万'],
#   'tag': ['ORG', 'p', 'v', 'v', 'n', 'w', 'n', 'v', 'v', 'm']},
#  {'word': ['王艺迪', '4', '-', '1', '孙颖莎', ' ', '夺', '女单', '冠军'],
#   'tag': ['PER', 'm', 'w', 'm', 'PER', 'w', 'v', 'n', 'n']},
#  {'word': ['理想', '汽车', '回应', 'L9试驾车空悬断裂'], 'tag': ['a', 'n', 'v', 'nz']},
#  {'word': ['甘肃', '昨', '增', '本土', '28', '+', '183例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['电视剧', '《', '张卫国的夏天', '》', '有', '哪些', '看点'],
#   'tag': ['n', 'w', 'nw', 'w', 'v', 'r', 'n']},
#  {'word': ['男子', '健身房', '洗澡', '被', '女子', '看光', '向', '店家', '索赔'],
#   'tag': ['n', 'n', 'v', 'p', 'n', 'v', 'p', 'n', 'v']},
#  {'word': ['男篮', '亚洲', '杯', '对阵', '：', '中国男篮', '将', '战', '印尼'],
#   'tag': ['n', 'LOC', 'n', 'v', 'w', 'ORG', 'd', 'v', 'LOC']},
#  {'word': ['癌症', '晚期', '妈妈', '想', '卖', '车', '续命', '陪', '孩子'],
#   'tag': ['n', 't', 'n', 'v', 'v', 'n', 'v', 'v', 'n']},
#  {'word': ['第40届', '金像奖', '获奖', '名单', '公布'],
#   'tag': ['m', 'nz', 'vn', 'n', 'v']},
#  {'word': ['纽约', '近', '万个', '猴痘疫苗', '名额', '10分钟', '抢', '空'],
#   'tag': ['LOC', 'ad', 'm', 'nz', 'n', 'TIME', 'v', 'a']},
#  {'word': ['网', '红', '用', '警用', '飞机', '拍', '视频', '？', '警方', '通报'],
#   'tag': ['n', 'a', 'p', 'a', 'n', 'v', 'n', 'w', 'n', 'v']},
#  {'word': ['美国', '两架', '小型', '飞机', '相撞', '致', '多', '人', '死亡'],
#   'tag': ['LOC', 'm', 'a', 'n', 'v', 'v', 'a', 'n', 'v']},
#  {'word': ['美国', '前', '国防部长', '窜访', '台湾'],
#   'tag': ['LOC', 'f', 'n', 'v', 'LOC']},
#  {'word': ['美国', '援', '乌无人机', '被曝', '在', '黑市', '半价', '出售'],
#   'tag': ['LOC', 'v', 'nz', 'v', 'p', 'n', 'n', 'v']},
#  {'word': ['美国', '猴痘', '病例', '增多', ' ', '疫苗', '供不应求'],
#   'tag': ['LOC', 'n', 'n', 'v', 'w', 'n', 'v']},
#  {'word': ['美国', '跨', '性别', '囚犯', '被曝', '致', '2名', '女囚', '怀孕'],
#   'tag': ['LOC', 'v', 'n', 'n', 'v', 'v', 'm', 'n', 'v']},
#  {'word': ['美媒', '关注', '俄', '版', '“', '航母杀手', '”', '弹道导弹'],
#   'tag': ['n', 'v', 'LOC', 'n', 'w', 'n', 'w', 'nz']},
#  {'word': ['老奶奶', '打扫', '完', '想', '休息', ' ', '狗狗', '推', '来', '椅子'],
#   'tag': ['n', 'v', 'v', 'v', 'vn', 'w', 'n', 'v', 'v', 'n']},
#  {'word': ['职工', '为', '运输', '方便', '砍', '物流园', '20棵', '树'],
#   'tag': ['n', 'p', 'vn', 'ad', 'v', 'n', 'm', 'n']},
#  {'word': ['英国', '外长', '：', '若', '当选', '首相', '愿', '与', '普京', '会晤'],
#   'tag': ['LOC', 'n', 'w', 'c', 'v', 'n', 'v', 'p', 'PER', 'v']},
#  {'word': ['英国', '被俘', '雇佣', '兵', '求助', '约翰逊'],
#   'tag': ['LOC', 'v', 'v', 'n', 'v', 'PER']},
#  {'word': ['西安', '工人', '因', '热射病', '去世', ' ', '工地', '将', '赔偿'],
#   'tag': ['LOC', 'n', 'p', 'n', 'v', 'w', 'n', 'd', 'v']},
#  {'word': ['西班牙', '本轮', '高温', '造成', '至少', '360', '人', '死亡'],
#   'tag': ['LOC', 'r', 'n', 'v', 'd', 'ORG', 'n', 'v']},
#  {'word': ['谢贤成', '金像奖', '最', '年长', '影帝'],
#   'tag': ['PER', 'nz', 'd', 'a', 'n']},
#  {'word': ['谢贤', '有', '哪些', '经典', '作品'], 'tag': ['PER', 'v', 'r', 'a', 'n']},
#  {'word': ['谢贤', '谢霆锋', '金像奖', '父子', '影帝'],
#   'tag': ['PER', 'PER', 'nz', 'n', 'n']},
#  {'word': ['谢霆锋', '祝贺', '谢贤', '获', '影帝'],
#   'tag': ['PER', 'v', 'PER', 'v', 'n']},
#  {'word': ['贾跃亭', '被', '恢复', '执行', '10亿元'],
#   'tag': ['PER', 'p', 'v', 'v', 'm']},
#  {'word': ['超重', '0.6斤', '不', '给', '走', '绿通', '？', '收费站', '：', '口误'],
#   'tag': ['v', 'm', 'd', 'v', 'v', 'n', 'w', 'n', 'w', 'n']},
#  {'word': ['轻松', '到家', '：', '暂停', '全部', '业务', '销售', '、', '交付'],
#   'tag': ['a', 'vn', 'w', 'v', 'n', 'n', 'vn', 'w', 'v']},
#  {'word': ['达美航空', '被曝', '将', '购', '百架', '波音', '737Max10'],
#   'tag': ['ORG', 'v', 'd', 'v', 'm', 'n', 'm']},
#  {'word': ['通俄', '叛国', '？', '乌克兰', '两名', '高官', '被解职'],
#   'tag': ['LOC', 'v', 'w', 'LOC', 'm', 'n', 'v']},
#  {'word': ['金像奖', '40年', '留给', '我们', '的', '珍贵', '记忆'],
#   'tag': ['nz', 'TIME', 'v', 'r', 'u', 'a', 'n']},
#  {'word': ['金像奖', '致敬', '已故', '电影', '人'], 'tag': ['nz', 'v', 'vn', 'n', 'n']},
#  {'word': ['银保监会', '：', '陆续', '启动', '5万元', '以上', '客户', '垫付'],
#   'tag': ['ORG', 'w', 'd', 'v', 'm', 'f', 'n', 'v']},
#  {'word': ['银行', '人脸', '识别', '系统', '被', '攻破'],
#   'tag': ['n', 'n', 'v', 'n', 'p', 'v']},
#  {'word': ['问', '天', '实验舱', '飞行', '任务', '标识', '发布'],
#   'tag': ['v', 'q', 'n', 'vn', 'n', 'n', 'v']},
#  {'word': ['防疫', '不力', ' ', '广西北海卫健委', '主任', '等', '被', '免'],
#   'tag': ['vn', 'a', 'w', 'ORG', 'n', 'u', 'p', 'v']},
#  {'word': ['陈时中', '战', '台北', '能', '拿', '几', '成选', '票'],
#   'tag': ['PER', 'v', 'LOC', 'v', 'v', 'm', 'v', 'n']},
#  {'word': ['隔离', '时', '家门', '被', '开锁', ' ', '广州', '：', '逐一', '道歉'],
#   'tag': ['v', 'n', 'n', 'p', 'v', 'w', 'LOC', 'w', 'd', 'v']},
#  {'word': ['韦世豪', '与', '妻子', '举行', '婚礼'], 'tag': ['PER', 'c', 'n', 'v', 'n']},
#  {'word': ['韩国', '将', '延长', '旅行', '禁令', ' ', '涉及', '俄乌', '等', '7', '国'],
#   'tag': ['LOC', 'd', 'v', 'vn', 'n', 'w', 'v', 'LOC', 'u', 'm', 'n']},
#  {'word': ['韩国', '生菜', '涨', '到', '200韩元一片'],
#   'tag': ['LOC', 'n', 'v', 'v', 'm']},
#  {'word': ['风华高科', '造假', ' ', '受损', '投资者', '获', '赔', '约', '60%'],
#   'tag': ['ORG', 'v', 'w', 'v', 'n', 'v', 'vn', 'd', 'm']},
#  {'word': ['香港', '：', '近', '60%', '食用油', '样本', '检出', '致癌物'],
#   'tag': ['LOC', 'w', 'ad', 'm', 'n', 'n', 'v', 'n']},
#  {'word': ['马斯克', '核心', '圈', '内', '斗', ' ', '1.5万亿', '谁', '说了算'],
#   'tag': ['PER', 'n', 'n', 'f', 'v', 'w', 'm', 'r', 'v']},
#  {'word': ['骗子', '用', '假', '人脸', '盗', '刷', '女子', '银行', '账户', '43万'],
#   'tag': ['n', 'p', 'a', 'n', 'v', 'v', 'n', 'n', 'n', 'm']},
#  {'word': ['黄金', '价格', '连续', '下跌', '刺激', '消费'],
#   'tag': ['n', 'n', 'ad', 'v', 'vn', 'vn']},
#  {'word': ['2022', '软科', '世界', '一流', '学科', '排名', '出炉'],
#   'tag': ['m', 'n', 'n', 'a', 'n', 'vn', 'v']},
#  {'word': ['2028', '洛杉矶奥运会', '开', '闭幕', '时间', '确定'],
#   'tag': ['m', 'nz', 'v', 'vn', 'n', 'v']},
#  {'word': ['23名', '教师', '被', '送', '东南亚', '读', '博', '？', '官方', '调查'],
#   'tag': ['m', 'n', 'p', 'v', 'LOC', 'v', 'v', 'w', 'n', 'v']},
#  {'word': ['26个', '省会', '常住', '人口', '数据', '：', '8', '城', '超', '千万'],
#   'tag': ['m', 'n', 'vn', 'n', 'n', 'w', 'm', 'n', 'v', 'm']},
#  {'word': ['31', '省份', '昨', '增', '本土', '199', '+', '500例'],
#   'tag': ['m', 'n', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['31', '省份', '昨', '增', '本土', '“', '199', '+', '500', '”', '例'],
#   'tag': ['m', 'n', 't', 'v', 'n', 'w', 'm', 'w', 'm', 'w', 'n']},
#  {'word': ['36岁', '女子', '升级', '当', '“', '奶奶', '”', ' ', '二胎', '才', '7岁'],
#   'tag': ['m', 'n', 'v', 'v', 'w', 'n', 'w', 'w', 'n', 'd', 'm']},
#  {'word': ['4S店', '员工', '性侵', '少女', '？', '天津', '警方', '回应'],
#   'tag': ['n', 'n', 'v', 'n', 'w', 'LOC', 'n', 'v']},
#  {'word': ['7旬', '大爷', '相亲', '后', '带', '前妻', '住', '女友', '家'],
#   'tag': ['m', 'n', 'v', 'f', 'v', 'n', 'v', 'n', 'n']},
#  {'word': ['95后', '女生', '因', '催', '婚', '焦虑', '过度碱中毒'],
#   'tag': ['t', 'n', 'p', 'v', 'n', 'a', 'vn']},
#  {'word': ['98岁', '“', '扫地僧', '”', '每天', '坐', '公交', '上班', '9小时'],
#   'tag': ['m', 'w', 'nz', 'w', 'TIME', 'v', 'n', 'v', 'TIME']},
#  {'word': ['iQOO', ' ', '10', ' ', 'Pro', '评测'],
#   'tag': ['nz', 'w', 'm', 'w', 'nz', 'v']},
#  {'word': ['iQOO10', '发布', '：', '手机', '充电', '是', '越', '快', '越好', '吗'],
#   'tag': ['nz', 'v', 'w', 'n', 'vn', 'v', 'd', 'a', 'a', 'xc']},
#  {'word': ['Stellantis', '将', '独自', '在', '华', '发展', 'Jeep', '品牌'],
#   'tag': ['nr', 'd', 'd', 'p', 'ns', 'v', 'nz', 'n']},
#  {'word': ['Ulike脱毛仪', '发布', '低俗', '广告', '被', '罚', '30万'],
#   'tag': ['nz', 'v', 'a', 'n', 'p', 'v', 'm']},
#  {'word': ['“',
#    '制',
#    '枪',
#    '村',
#    '”',
#    '的',
#    '二十年',
#    '：',
#    '如何',
#    '走出',
#    '罪',
#    '与',
#    '穷'],
#   'tag': ['w',
#    'v',
#    'n',
#    'n',
#    'w',
#    'u',
#    'TIME',
#    'w',
#    'r',
#    'v',
#    'n',
#    'c',
#    'an']},
#  {'word': ['“', '小天才', '”', '平板', '涉黄', '涉', '暴', '被', '约谈'],
#   'tag': ['w', 'nr', 'w', 'n', 'v', 'v', 'an', 'p', 'v']},
#  {'word': ['“', '集中供冷', '”', '能', '大力', '推广', '吗'],
#   'tag': ['w', 'vn', 'w', 'v', 'd', 'v', 'xc']},
#  {'word': ['《', '人生若如初见', '》', '因', '技术', '原因', '延后', '播出'],
#   'tag': ['w', 'nw', 'w', 'p', 'n', 'n', 'v', 'v']},
#  {'word': ['《', '幸福到万家', '》', '王庆', '来', '身上', '的', '众生', '相'],
#   'tag': ['w', 'nw', 'w', 'PER', 'v', 's', 'u', 'n', 'n']},
#  {'word': ['《', '庭外', '》', '里', '的', '丧偶式', '育儿', '你', '怎么', '看'],
#   'tag': ['w', 'nw', 'w', 'f', 'u', 'a', 'v', 'r', 'r', 'v']},
#  {'word': ['《', '张卫国的夏天', '》', '里', '中年人', '的', '无奈'],
#   'tag': ['w', 'nw', 'w', 'f', 'n', 'u', 'an']},
#  {'word': ['《', '张卫国的夏天', '》', '首播', '口碑', '如何'],
#   'tag': ['w', 'nw', 'w', 'v', 'n', 'r']},
#  {'word': ['《', '张卫国的夏天', '》', '黄磊', '聊', '张卫国', '的', '困境'],
#   'tag': ['w', 'nw', 'w', 'PER', 'v', 'PER', 'u', 'n']},
#  {'word': ['《', '新闻联播', '》', '正在', '直播'], 'tag': ['w', 'nw', 'w', 'd', 'v']},
#  {'word': ['一位', '父亲', '与', '罕见病', '儿子', '走过', '的', '18年'],
#   'tag': ['m', 'n', 'p', 'n', 'n', 'v', 'u', 'TIME']},
#  {'word': ['一分钱', '酸菜鱼', '能', '拯救', '趣', '店', '吗'],
#   'tag': ['m', 'nz', 'v', 'v', 'n', 'n', 'xc']},
#  {'word': ['上半年', '我', '国', '新能源车', '“', '产销两旺', '”'],
#   'tag': ['TIME', 'r', 'n', 'nz', 'w', 'nz', 'w']},
#  {'word': ['上海一小区', '79棵', '大树', '修剪', '后', '枯死', '5年'],
#   'tag': ['LOC', 'm', 'n', 'v', 'f', 'v', 'TIME']},
#  {'word': ['上海', '昨', '增', '本土', '病例', '“', '4', '+', '19', '”'],
#   'tag': ['LOC', 't', 'v', 'n', 'n', 'w', 'm', 'w', 'm', 'w']},
#  {'word': ['下届', '篮球', '世界杯', '主办', '国', '印尼', '无缘', '参赛'],
#   'tag': ['r', 'n', 'n', 'v', 'n', 'LOC', 'v', 'vn']},
#  {'word': ['专家', '评', '博士', '量产', '：', '洋文凭认证', '迫在眉睫'],
#   'tag': ['n', 'v', 'n', 'vn', 'w', 'nz', 'v']},
#  {'word': ['专家', '：', '应避免', '下半年', '把', '经济', '推', '至', '过热'],
#   'tag': ['n', 'w', 'v', 'TIME', 'p', 'n', 'v', 'v', 'an']},
#  {'word': ['世纪佳缘', '回应', '多名', '高管', '被', '调查'],
#   'tag': ['ORG', 'v', 'm', 'n', 'p', 'v']},
#  {'word': ['东亚杯', '：', '日本女足', '2', '-', '1', '韩国', '取', '开门红'],
#   'tag': ['nz', 'w', 'ORG', 'm', 'w', 'm', 'LOC', 'v', 'n']},
#  {'word': ['东亚杯', '：', '日本男足', '6', '-', '0', '中国香港队'],
#   'tag': ['nz', 'w', 'ORG', 'm', 'w', 'm', 'ORG']},
#  {'word': ['东北', '女人', '中东', '经商', '20年', '国内', '攒', '4', '套房'],
#   'tag': ['LOC', 'n', 'LOC', 'v', 'TIME', 's', 'v', 'm', 'n']},
#  {'word': ['东莞库珀电子', '实', '控', '人', '回应', '停产', '结业'],
#   'tag': ['ORG', 'ad', 'v', 'n', 'v', 'v', 'v']},
#  {'word': ['两', '男子', '景区', '悬崖边', '脚踢', '巨石'],
#   'tag': ['m', 'n', 'n', 's', 'n', 'n']},
#  {'word': ['中信证券', '研究', '团队', '拆解', '特斯拉', '出', '研报'],
#   'tag': ['ORG', 'vn', 'n', 'v', 'PER', 'v', 'n']},
#  {'word': ['中信银行南昌分行', '原', '副行长', '姚蔚', '出狱'],
#   'tag': ['ORG', 'a', 'n', 'PER', 'v']},
#  {'word': ['中国中铁', '中标', '合计', '961.85亿', '工程', '项目'],
#   'tag': ['ORG', 'v', 'v', 'm', 'n', 'n']},
#  {'word': ['中国', '内地', '两周', '现', '10种', '奥密克戎变异株'],
#   'tag': ['LOC', 's', 'TIME', 't', 'm', 'nz']},
#  {'word': ['中国矿产资源集团', '成立', ' ', '注册资本', '200亿'],
#   'tag': ['ORG', 'v', 'w', 'nz', 'm']},
#  {'word': ['中国', '科学家', '成功', '破译', '裸燕麦', '基因', '密码'],
#   'tag': ['LOC', 'n', 'ad', 'v', 'nz', 'n', 'n']},
#  {'word': ['中国', '美债持仓', '12年', '来', '首', '破', '1万亿美元'],
#   'tag': ['LOC', 'nz', 'TIME', 'v', 'm', 'v', 'm']},
#  {'word': ['中国', '邀', '4个', '欧洲', '国家', '领导人', '访京', '？', '假', '的'],
#   'tag': ['LOC', 'v', 'm', 'LOC', 'n', 'n', 'v', 'w', 'a', 'u']},
#  {'word': ['中国', '队', '包揽', '物理', '奥赛', '世界', '前', '五'],
#   'tag': ['LOC', 'n', 'v', 'n', 'nz', 'n', 'f', 'm']},
#  {'word': ['中国', '首列', '胶轮', '地铁', '列车', '出口', '海外'],
#   'tag': ['LOC', 'm', 'n', 'n', 'n', 'v', 's']},
#  {'word': ['中通客车', '股价', '盘中', '上演', '“', '天地板', '”'],
#   'tag': ['ORG', 'n', 's', 'v', 'w', 'n', 'w']},
#  {'word': ['中通客车', '：', '山东国投', '减持', '1%', '公司', '股份'],
#   'tag': ['ORG', 'w', 'ORG', 'v', 'm', 'n', 'n']},
#  {'word': ['乌克兰', '议员', '被', '要求', '当众', '脱下', '军装'],
#   'tag': ['LOC', 'n', 'p', 'v', 'd', 'v', 'n']},
#  {'word': ['习酒集团', '成立', ' ', '注册资本', '37.5亿元'],
#   'tag': ['ORG', 'v', 'w', 'nz', 'm']},
#  {'word': ['京广隧道', '“', '吹哨人', '”', '再', '忆', '郑州', '720', '暴雨'],
#   'tag': ['LOC', 'w', 'nz', 'w', 'd', 'v', 'LOC', 'nz', 'n']},
#  {'word': ['伊之密', '实', '控', '人', '、', '董事长', '陈敬财', '逝世'],
#   'tag': ['ORG', 'ad', 'v', 'n', 'w', 'n', 'PER', 'v']},
#  {'word': ['伊媒', '：', '俄伊', '签署', '400亿美元', '协议'],
#   'tag': ['ORG', 'w', 'LOC', 'v', 'm', 'n']},
#  {'word': ['传', '苹果', '将', '放缓', '部分', '领域', '招聘', '工作'],
#   'tag': ['v', 'ORG', 'd', 'v', 'n', 'n', 'vn', 'n']},
#  {'word': ['余秀华', '前男友', '直播', '自扇', '100个', '耳光'],
#   'tag': ['PER', 'n', 'v', 'n', 'm', 'n']},
#  {'word': ['俄', '公布', '乌军', '机库', '被', '炸', '第一', '视角', '画面'],
#   'tag': ['LOC', 'v', 'n', 'n', 'p', 'v', 'm', 'n', 'n']},
#  {'word': ['俄军', '如何', '应对', '“', '海马斯', '”', '多管', '火箭炮'],
#   'tag': ['n', 'r', 'v', 'w', 'PER', 'w', 'v', 'n']},
#  {'word': ['俄军', '打击', '顿涅茨克', '外国', '雇佣兵', '部署', '点'],
#   'tag': ['n', 'v', 'LOC', 'n', 'n', 'v', 'n']},
#  {'word': ['俄媒', '：', '中国', '轰炸机', '将', '胜过', '美国', '夜鹰'],
#   'tag': ['n', 'w', 'LOC', 'n', 'd', 'v', 'LOC', 'n']},
#  {'word': ['俄方', '从', '作战', '行动', '上', '控制', '谢韦尔斯克'],
#   'tag': ['n', 'p', 'vn', 'n', 'f', 'v', 'PER']},
#  {'word': ['俄气', '向', '部分', '欧洲', '客户', '宣布', '遇', '不可', '抗力'],
#   'tag': ['n', 'p', 'n', 'LOC', 'n', 'v', 'v', 'v', 'n']},
#  {'word': ['俄', '称', '在', '乌', '军事', '行动', '无', '明确', '时间', '框架'],
#   'tag': ['LOC', 'v', 'p', 'ns', 'n', 'n', 'v', 'a', 'n', 'n']},
#  {'word': ['俄罗斯', '和', '伊朗', '双边', '交易', '将', '放弃', '美元'],
#   'tag': ['LOC', 'c', 'LOC', 'n', 'n', 'd', 'v', 'nz']},
#  {'word': ['俄', '若', '不', '恢复', '供气', '对', '欧洲', '经济', '意味着', '啥'],
#   'tag': ['LOC', 'c', 'd', 'v', 'vn', 'p', 'LOC', 'n', 'v', 'r']},
#  {'word': ['俩', '黑客', '出狱', '后', '5天', '非法', '获利', '200万'],
#   'tag': ['m', 'n', 'v', 'f', 'TIME', 'd', 'v', 'm']},
#  {'word': ['全国', '超过', '40%', '的', '两院', '院士', '集聚', '在', '高校'],
#   'tag': ['n', 'v', 'm', 'u', 'n', 'n', 'v', 'p', 'n']},
#  {'word': ['公司', '回应', '配音', '演员', '姜广涛', '被', '警察', '带走'],
#   'tag': ['n', 'v', 'v', 'n', 'PER', 'p', 'n', 'v']},
#  {'word': ['公安部', '要求', '严打', '网络', '水军'], 'tag': ['ORG', 'v', 'v', 'n', 'n']},
#  {'word': ['公安部', '：', '严防', '发生', '个人', '极端', '暴力', '事件'],
#   'tag': ['ORG', 'w', 'v', 'v', 'n', 'n', 'n', 'n']},
#  {'word': ['兰州', '24小时', '新增', '本土', '29', '+', '140例'],
#   'tag': ['LOC', 'TIME', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['共青团中央', '：', '嘲讽', '小镇', '做题', '家', '是', '病'],
#   'tag': ['ORG', 'w', 'v', 'n', 'v', 'n', 'v', 'n']},
#  {'word': ['冷饮', '摊', '私', '拉', '电线', '偷', '公安局', '天眼', '的', '电'],
#   'tag': ['n', 'v', 'ad', 'v', 'n', 'v', 'n', 'n', 'u', 'n']},
#  {'word': ['冻结', '俄', '近', '300亿欧元', ' ', '欧盟', '计划', '怎么', '花'],
#   'tag': ['v', 'LOC', 'ad', 'm', 'w', 'ORG', 'n', 'r', 'v']},
#  {'word': ['刘畊宏', '在', '周杰伦', '直播', '时', '送', '奶茶', '礼物'],
#   'tag': ['PER', 'p', 'PER', 'v', 'n', 'v', 'n', 'n']},
#  {'word': ['刘雅瑟', '获', '金像奖', '影后', ' ', '发文', '感谢'],
#   'tag': ['PER', 'v', 'nz', 'n', 'w', 'vn', 'vn']},
#  {'word': ['加纳', '2例', '确诊', '马尔堡病毒', '患者', '已', '去世'],
#   'tag': ['LOC', 'm', 'v', 'nz', 'n', 'd', 'v']},
#  {'word': ['北京', '2022年', '社保', '缴费', '工资', '基数', '公布'],
#   'tag': ['LOC', 'TIME', 'n', 'vn', 'n', 'n', 'v']},
#  {'word': ['北京', '一', '感染者', '健康', '监测期', '曾', '擅自', '外出'],
#   'tag': ['LOC', 'm', 'n', 'a', 'n', 'd', 'd', 'v']},
#  {'word': ['北京', '昨', '增', '1例', '本土', '无', '症状', ' ', '系', '隔离', '人员'],
#   'tag': ['LOC', 't', 'v', 'm', 'n', 'v', 'n', 'w', 'v', 'vn', 'n']},
#  {'word': ['北京酒店', '不得', '拒绝', '健康', '码', '异常', '人员', '入住'],
#   'tag': ['ORG', 'v', 'v', 'an', 'n', 'a', 'n', 'v']},
#  {'word': ['北京', '：', '全市', '酒店', '不', '承办', '婚宴', '、', '生日', '宴'],
#   'tag': ['LOC', 'w', 'n', 'n', 'd', 'v', 'n', 'w', 'n', 'n']},
#  {'word': ['北溪', '-', '1', '关闭', '一周后', ' ', '欧洲', '担忧', '加剧'],
#   'tag': ['ns', 'w', 'm', 'v', 'TIME', 'w', 'LOC', 'v', 'v']},
#  {'word': ['华为Mate', ' ', '50', '系列', '最新', '渲染', '图', '泄露'],
#   'tag': ['nz', 'w', 'm', 'n', 'a', 'vn', 'n', 'v']},
#  {'word': ['华为', '鸿蒙', '3.0', '系统', '7月27日', '发布'],
#   'tag': ['ORG', 'n', 'm', 'n', 'TIME', 'v']},
#  {'word': ['南方', '预计', '将', '从', '21日', '热', '到', '月底'],
#   'tag': ['s', 'v', 'd', 'p', 'TIME', 'ad', 'v', 'TIME']},
#  {'word': ['印', '扣押俄', '军', '火船', ' ', '原因', '与', '燃油', '费', '有关'],
#   'tag': ['v', 'vn', 'n', 'n', 'w', 'n', 'p', 'n', 'n', 'v']},
#  {'word': ['只', '会', '电脑', '开', '关机', '的', '少年', '高考', '632分'],
#   'tag': ['d', 'v', 'n', 'v', 'v', 'u', 'n', 'n', 'm']},
#  {'word': ['可可西里', '发现', '罕见', '红', '山脉'], 'tag': ['LOC', 'v', 'a', 'a', 'n']},
#  {'word': ['台湾', '捕获', '灰六鳃鲨', ' ', '或', '比', '恐龙', '更古', '老'],
#   'tag': ['LOC', 'v', 'nz', 'w', 'c', 'p', 'n', 'a', 'a']},
#  {'word': ['台湾', '新增', '27146例', '确诊', '、', '37例', '死亡'],
#   'tag': ['LOC', 'v', 'm', 'v', 'w', 'm', 'v']},
#  {'word': ['同事', '在', '背后', '说', '我', '坏话', '怎么', '办'],
#   'tag': ['n', 'p', 's', 'v', 'r', 'n', 'r', 'v']},
#  {'word': ['名记', '：', '湖人', '可能', '达成', '不止', '一笔', '交易'],
#   'tag': ['n', 'w', 'ORG', 'v', 'v', 'v', 'm', 'n']},
#  {'word': ['听', '中欧', '企业', '讲述', '欧元', '贬值', '冲击'],
#   'tag': ['v', 'ns', 'n', 'v', 'nz', 'v', 'vn']},
#  {'word': ['周江勇', '家族', '的', '灰色', '“', '人', '世间', '”'],
#   'tag': ['PER', 'n', 'u', 'n', 'w', 'n', 'n', 'w']},
#  {'word': ['四川', '昨', '增', '本土', '12', '+', '12例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['国内', '油价', '有望', '迎来', '“', '3', '连', '降', '”'],
#   'tag': ['s', 'n', 'v', 'v', 'w', 'm', 'd', 'v', 'w']},
#  {'word': ['国台办', '回应', '美', '对', '台', '军售', '：', '敦促', '停止', '玩火'],
#   'tag': ['ORG', 'v', 'ns', 'p', 'ns', 'n', 'w', 'v', 'v', 'vn']},
#  {'word': ['国防部', '：', '美', '应', '立即', '撤销', '对', '台', '军售', '计划'],
#   'tag': ['ORG', 'w', 'ns', 'v', 'd', 'v', 'p', 'n', 'vn', 'n']},
#  {'word': ['土耳其', '总统', '再就', '芬兰', '瑞典', '入', '约', '敲', '警钟'],
#   'tag': ['LOC', 'n', 'v', 'LOC', 'LOC', 'v', 'd', 'v', 'n']},
#  {'word': ['城管', '查', '车', '未', '穿', '制服', '？', '城管局', '：', '正', '制作'],
#   'tag': ['n', 'v', 'n', 'd', 'v', 'n', 'w', 'n', 'w', 'd', 'v']},
#  {'word': ['基根·穆雷', '当选', '本年度', '夏季', '联赛', 'MVP'],
#   'tag': ['PER', 'v', 'TIME', 'TIME', 'n', 'nz']},
#  {'word': ['外交部', '回应', '美方', '官员', '威胁'], 'tag': ['nt', 'v', 'n', 'n', 'v']},
#  {'word': ['外交部', '批', '美', '前', '防长', '涉', '一中', '政策', '言论'],
#   'tag': ['nt', 'v', 'an', 'f', 'v', 'v', 'n', 'n', 'n']},
#  {'word': ['外交部', '：', '要求', '美方', '不得', '安排', '佩洛西', '访台'],
#   'tag': ['nt', 'w', 'v', 'n', 'v', 'v', 'PER', 'v']},
#  {'word': ['外卖员', '被撞', '倒', '又', '遭', '碾压', '？', '警方', '通报'],
#   'tag': ['n', 'v', 'd', 'd', 'v', 'v', 'w', 'n', 'v']},
#  {'word': ['外媒', '：', '美众议院', '议长', '佩洛西', '拟', '8月', '访台'],
#   'tag': ['n', 'w', 'n', 'n', 'PER', 'v', 'TIME', 'v']},
#  {'word': ['多家', '银行', '对', '贵金属', '交易', '调整', '力度', '升级'],
#   'tag': ['m', 'n', 'p', 'n', 'vn', 'vn', 'n', 'v']},
#  {'word': ['天津一小区', '发生', '爆炸', '：', '六层', '建筑', '损毁'],
#   'tag': ['LOC', 'v', 'vn', 'w', 'm', 'n', 'vn']},
#  {'word': ['天津', '一', '居民楼', '燃', '爆致', '8', '人', '受伤'],
#   'tag': ['LOC', 'm', 'n', 'v', 'v', 'm', 'n', 'v']},
#  {'word': ['天津', '北辰一小区', '发生', '爆炸', '事故'],
#   'tag': ['LOC', 'LOC', 'v', 'vn', 'n']},
#  {'word': ['天津', '居民楼', '燃', '爆', '已', '致', '10', '人', '受伤'],
#   'tag': ['LOC', 'n', 'v', 'vn', 'd', 'v', 'm', 'n', 'v']},
#  {'word': ['天津', '居民楼', '燃', '爆致10伤', ' ', '直击', '现场'],
#   'tag': ['LOC', 'n', 'v', 'nz', 'w', 'v', 's']},
#  {'word': ['天津', '居民楼', '燃', '爆', '致', '11', '人', '受伤', '3', '人', '失联'],
#   'tag': ['LOC', 'n', 'v', 'v', 'v', 'm', 'n', 'v', 'm', 'n', 'v']},
#  {'word': ['天津', '爆炸', '小区', '多', '是', '老年', '人和', '租户'],
#   'tag': ['LOC', 'v', 'n', 'd', 'v', 'n', 'n', 'n']},
#  {'word': ['天津爆燃事故', '为', '恶意', '报复', '炸', '楼', '？', '假', '的'],
#   'tag': ['nz', 'v', 'n', 'v', 'v', 'n', 'w', 'a', 'u']},
#  {'word': ['天津', '警方', '通报', '“', '女子', '强行', '抱', '走', '男童', '”'],
#   'tag': ['LOC', 'n', 'v', 'w', 'n', 'd', 'v', 'v', 'n', 'w']},
#  {'word': ['太阳', '官方', '宣布', '4年', '1.33亿', '留下', '艾顿'],
#   'tag': ['n', 'n', 'v', 'TIME', 'm', 'v', 'PER']},
#  {'word': ['央媒', '评为', '防疫', '拆', '住户', '门锁', '：', '离', '大谱'],
#   'tag': ['n', 'v', 'vn', 'v', 'n', 'n', 'w', 'v', 'n']},
#  {'word': ['央行', '将', '发行', '世界', '遗产', '金银', '纪念币'],
#   'tag': ['ORG', 'd', 'v', 'n', 'n', 'n', 'n']},
#  {'word': ['女子', '1448万', '买法', '拍', '楼', ' ', '原', '房东', '阻挠', '装修'],
#   'tag': ['n', 'm', 'n', 'v', 'n', 'w', 'a', 'n', 'v', 'vn']},
#  {'word': ['女子', '从', '骑车', '老人', '后座', '强行', '抱', '走', '男童'],
#   'tag': ['n', 'p', 'vn', 'n', 'n', 'd', 'v', 'v', 'n']},
#  {'word': ['女子', '体温', '40.6', '°', 'C', '突发', '热射病', '死亡'],
#   'tag': ['n', 'n', 'm', 'w', 'm', 'vn', 'n', 'v']},
#  {'word': ['女子', '找工作', '不', '接受', '单休', '被', 'HR', '骂'],
#   'tag': ['n', 'v', 'd', 'v', 'PER', 'p', 'nz', 'v']},
#  {'word': ['女子', '科目', '三', '考试', '把', '安全员', '整', '吐', '了'],
#   'tag': ['n', 'n', 'm', 'vn', 'p', 'n', 'v', 'v', 'xc']},
#  {'word': ['女子', '等', '电梯', '时', '无故', '遭', '陌生人', '撞击'],
#   'tag': ['n', 'u', 'n', 'n', 'd', 'v', 'n', 'v']},
#  {'word': ['女子', '给', '儿子', '熬', '中药', '炼', '出', '一炉', '“', '仙丹', '”'],
#   'tag': ['n', 'p', 'n', 'v', 'n', 'v', 'v', 'm', 'w', 'n', 'w']},
#  {'word': ['女子', '自学', '绘画', '在', '停车位画', '“', '招财猫', '”'],
#   'tag': ['n', 'v', 'n', 'p', 'nz', 'w', 'n', 'w']},
#  {'word': ['女子', '被', '丈夫', '家暴', ' ', '女儿', '喝', '止', '后', '报警'],
#   'tag': ['n', 'p', 'n', 'n', 'w', 'n', 'v', 'v', 'f', 'v']},
#  {'word': ['女孩', '遭', '轿车', '碾压', '后', '奇迹', '生还'],
#   'tag': ['n', 'v', 'n', 'v', 'f', 'n', 'v']},
#  {'word': ['女生', '给', '一千个', '陌生人', '写信'], 'tag': ['n', 'p', 'm', 'n', 'v']},
#  {'word': ['女', '顾客', '称', '“', '要', '让', '老板娘', '从', '汉中', '消失', '”'],
#   'tag': ['a', 'n', 'v', 'w', 'v', 'v', 'n', 'p', 'LOC', 'v', 'w']},
#  {'word': ['姜广涛', '公司', '声明'], 'tag': ['PER', 'n', 'v']},
#  {'word': ['媒体', '评引', '进', '菲律宾', '博士', '：', '歪门', '邪道'],
#   'tag': ['n', 'v', 'v', 'LOC', 'n', 'w', 'v', 'n']},
#  {'word': ['媒体', '：', '世纪佳缘', '“', '失联', '”', '高管', '已', '被刑拘'],
#   'tag': ['n', 'w', 'ORG', 'w', 'vn', 'w', 'n', 'd', 'v']},
#  {'word': ['媒体', '：', '为何', '各国', '都', '在', '减持', '美', '债'],
#   'tag': ['n', 'w', 'r', 'n', 'd', 'd', 'v', 'a', 'n']},
#  {'word': ['媒体', '：', '张小泉', '的', '危机', '不', '只是', '不能', '拍', '蒜'],
#   'tag': ['n', 'w', 'PER', 'u', 'n', 'd', 'v', 'v', 'v', 'n']},
#  {'word': ['媒体', '：', '理性', '看待', '上半年', '居民', '存款', '大增'],
#   'tag': ['n', 'w', 'n', 'v', 'TIME', 'n', 'n', 'v']},
#  {'word': ['孙春兰', '：', '第九版', '防控', '方案', '不是', '放松'],
#   'tag': ['PER', 'w', 'm', 'vn', 'n', 'v', 'v']},
#  {'word': ['宁夏', '发现', '1例', '鼠疫', '病例'], 'tag': ['LOC', 'v', 'm', 'n', 'n']},
#  {'word': ['安徽', '怀远县', '连续', '7天', '喷', '3小时', '过氧', '乙酸'],
#   'tag': ['LOC', 'LOC', 'a', 'TIME', 'v', 'TIME', 'v', 'n']},
#  {'word': ['安徽',
#    '昨',
#    '增',
#    '本土',
#    '“',
#    '6',
#    '+',
#    '73',
#    '”',
#    ' ',
#    '在',
#    '亳州',
#    '蚌埠'],
#   'tag': ['LOC',
#    't',
#    'v',
#    'n',
#    'w',
#    'm',
#    'w',
#    'm',
#    'w',
#    'w',
#    'p',
#    'LOC',
#    'LOC']},
#  {'word': ['实探', '四川', '1', '死', '7', '伤泳池', '垮塌', '事故', '现场'],
#   'tag': ['v', 'LOC', 'm', 'v', 'm', 'n', 'v', 'n', 's']},
#  {'word': ['巴基斯坦', '前', '总理', '赢得', '旁遮普省', '补选'],
#   'tag': ['LOC', 'f', 'n', 'v', 'ns', 'v']},
#  {'word': ['广东', '一', '婴儿', '高温', '天', '被', '扔', '垃圾桶'],
#   'tag': ['LOC', 'm', 'n', 'n', 'n', 'p', 'v', 'n']},
#  {'word': ['广东', '上半年', 'GDP', '为', '5.95万亿元'],
#   'tag': ['LOC', 'TIME', 'n', 'v', 'm']},
#  {'word': ['广东', '上调', '养老金'], 'tag': ['LOC', 'v', 'n']},
#  {'word': ['广汽菲克合资公司', '解体'], 'tag': ['ORG', 'v']},
#  {'word': ['广西', '北海', '滞留', '游客', '：', '目前', '生活', '有', '保障'],
#   'tag': ['LOC', 'LOC', 'v', 'n', 'w', 't', 'n', 'v', 'vn']},
#  {'word': ['广西', '昨', '增', '本土', '134', '+', '109例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['张卫国', '的', '夏天', '喜剧', '刺客'],
#   'tag': ['PER', 'u', 'TIME', 'n', 'n']},
#  {'word': ['张小泉', '总经理', '道歉'], 'tag': ['PER', 'n', 'v']},
#  {'word': ['张小泉', '总经理', '：', '去年', '采访', '被', '截取', '挺冤', '的'],
#   'tag': ['PER', 'n', 'w', 'TIME', 'v', 'p', 'v', 'a', 'u']},
#  {'word': ['张小泉', '或', '研发', '拍', '蒜', '刀'],
#   'tag': ['PER', 'c', 'v', 'v', 'n', 'n']},
#  {'word': ['张小泉', '竞争对手', '直播', '菜刀', '拍', '蒜', '一整天'],
#   'tag': ['PER', 'n', 'vn', 'n', 'v', 'n', 'm']},
#  {'word': ['张小泉', '被曝', '剁', '鸡腿', '时', '折断', '：', '刀', '被', '弹飞'],
#   'tag': ['PER', 'v', 'v', 'n', 'n', 'v', 'w', 'n', 'p', 'v']},
#  {'word': ['张朝阳', '解释', '温室', '效应', '的', '形成'],
#   'tag': ['PER', 'v', 'n', 'n', 'u', 'vn']},
#  {'word': ['德方', '称', '欧盟', '不会', '因', '局势', '撤销', '对', '俄', '制裁'],
#   'tag': ['nr', 'v', 'ORG', 'v', 'p', 'n', 'v', 'p', 'LOC', 'v']},
#  {'word': ['怀孕', '妻子', '送', '海员', '丈夫', '离家', '后', '偷', '抹', '眼泪'],
#   'tag': ['vn', 'n', 'v', 'n', 'n', 'v', 'f', 'v', 'v', 'n']},
#  {'word': ['情侣', '吵架', '从', '十', '楼', '扔下', '菜刀', '砸', '中保洁员'],
#   'tag': ['n', 'v', 'p', 'm', 'n', 'v', 'n', 'v', 'ORG']},
#  {'word': ['情侣', '因', '房贷', '压力', '大', '住进', '毛坯', '新房'],
#   'tag': ['n', 'p', 'n', 'n', 'd', 'v', 'n', 'n']},
#  {'word': ['情', '满', '天山', ' ', '硕果累累'], 'tag': ['n', 'a', 'LOC', 'w', 'a']},
#  {'word': ['意大利政府', '危机', '未来', '走向', '何处'],
#   'tag': ['ORG', 'n', 't', 'v', 'r']},
#  {'word': ['成都', '全市', '酒吧', '等', '密闭', '空间', '暂停', '营业'],
#   'tag': ['LOC', 'n', 'n', 'u', 'vn', 'n', 'v', 'vn']},
#  {'word': ['我', '国', '新能源车', '产销', '两旺'], 'tag': ['r', 'n', 'nz', 'n', 'n']},
#  {'word': ['我', '舰艇', '编队', '赴', '北太平洋', '渔业', '执法', '巡航'],
#   'tag': ['r', 'n', 'n', 'v', 'LOC', 'n', 'vn', 'vn']},
#  {'word': ['戴世宏', '接受', '审查', '调查'], 'tag': ['PER', 'v', 'vn', 'vn']},
#  {'word': ['拜登', '考虑', '最', '快', '本周', '宣布', '气候', '紧急', '状态'],
#   'tag': ['PER', 'v', 'd', 'a', 'TIME', 'v', 'n', 'a', 'n']},
#  {'word': ['教育改革', '会', '影响', '小镇', '做题', '家', '的', '出路', '吗'],
#   'tag': ['vn', 'v', 'v', 'n', 'v', 'n', 'u', 'n', 'xc']},
#  {'word': ['斯里兰卡', '华人', '：', '银行存款', '蒸发', '了', '一半'],
#   'tag': ['LOC', 'n', 'w', 'n', 'v', 'u', 'm']},
#  {'word': ['新', 'iPhone', '部分', '机型', '或', '取消', 'SIM卡', '槽'],
#   'tag': ['a', 'nz', 'n', 'n', 'c', 'v', 'nz', 'n']},
#  {'word': ['新娘', '身穿', '蒙古袍', '礼服', '太', '惊艳'],
#   'tag': ['n', 'v', 'n', 'n', 'd', 'a']},
#  {'word': ['新疆', '暑期', '旅游', '爆火'], 'tag': ['LOC', 'TIME', 'v', 'v']},
#  {'word': ['新疆', '疑似', '出现', '火流星'], 'tag': ['LOC', 'v', 'v', 'nz']},
#  {'word': ['日', '媒', '称', '羽生结弦', '将', '宣布', '退役'],
#   'tag': ['ns', 'n', 'v', 'PER', 'd', 'v', 'vn']},
#  {'word': ['日本发明办公室', '站立', '午睡盒'], 'tag': ['ORG', 'v', 'n']},
#  {'word': ['日本海上保安厅', '一', '巡视船误射机关炮'], 'tag': ['ORG', 'm', 'nz']},
#  {'word': ['普京', '：', '俄', '将', '集中', '精力', '发展', '高新技术'],
#   'tag': ['PER', 'w', 'LOC', 'd', 'v', 'n', 'v', 'n']},
#  {'word': ['普京', '：', '俄罗斯', '不会', '倒退', '几十年'],
#   'tag': ['PER', 'w', 'LOC', 'v', 'v', 'TIME']},
#  {'word': ['曝', 'KD', '欧文', '接受', '不会', '很快', '被', '交易', '的', '现实'],
#   'tag': ['v', 'nz', 'PER', 'v', 'v', 'ad', 'p', 'v', 'u', 'n']},
#  {'word': ['杜锋', '：', '让', '王哲林', '担任', '队长', '是', '正确', '选择'],
#   'tag': ['PER', 'w', 'v', 'PER', 'v', 'n', 'v', 'a', 'vn']},
#  {'word': ['杨紫', '曾', '在', '雨天', '帮助', '拾', '荒', '老奶奶'],
#   'tag': ['PER', 'd', 'p', 'n', 'v', 'v', 'a', 'n']},
#  {'word': ['杭州', '亚运会', '将', '于', '2023年9月23日', '开幕'],
#   'tag': ['ns', 'nz', 'd', 'p', 'TIME', 'v']},
#  {'word': ['杭州', '亚运会', '将', '于', '明年9月23日', '举行'],
#   'tag': ['ns', 'nz', 'd', 'p', 'TIME', 'v']},
#  {'word': ['柯文哲', '在', '双城', '论坛', '感叹', '两岸关系', '恶化'],
#   'tag': ['PER', 'p', 'LOC', 'n', 'v', 'n', 'v']},
#  {'word': ['校方', '回应', '巨资', '引进', '菲律宾', '高校', '博士'],
#   'tag': ['n', 'v', 'n', 'v', 'LOC', 'n', 'n']},
#  {'word': ['校方', '回应', '花', '2000万', '引进', '菲律宾', '博士'],
#   'tag': ['n', 'v', 'v', 'm', 'v', 'LOC', 'n']},
#  {'word': ['梅德韦杰夫', '：', '美', '武器', '通过', '乌克兰', '扩散'],
#   'tag': ['PER', 'w', 'a', 'n', 'p', 'LOC', 'v']},
#  {'word': ['梦想', '照', '进', '现实', ' ', '努力', '终', '有', '回报'],
#   'tag': ['n', 'v', 'v', 'n', 'w', 'ad', 'd', 'v', 'vn']},
#  {'word': ['欧洲', '多国', '被', '“', '炙烤', '”', ' ', '能源', '危机', '加剧'],
#   'tag': ['LOC', 'n', 'p', 'w', 'vn', 'w', 'w', 'n', 'n', 'v']},
#  {'word': ['欧盟', '外长', '会同意', '禁止', '进口', '俄罗斯', '黄金'],
#   'tag': ['ORG', 'n', 'v', 'v', 'v', 'LOC', 'n']},
#  {'word': ['武契奇', '：', '乌', '失事', '货机', '装', '的', '是', '塞国', '武器'],
#   'tag': ['PER', 'w', 'ns', 'v', 'n', 'v', 'u', 'v', 'v', 'n']},
#  {'word': ['民调', '：', '陈时中', '参选', '台北', '支持率', '不', '乐观'],
#   'tag': ['n', 'w', 'PER', 'v', 'LOC', 'n', 'd', 'a']},
#  {'word': ['河北', '4', '少年', '同', '骑', '1辆', '电动车', '被撞', '身亡'],
#   'tag': ['LOC', 'm', 'n', 'd', 'v', 'm', 'n', 'v', 'v']},
#  {'word': ['河北', '正定', '重型半挂车', '撞', '电动车', '致', '4', '死'],
#   'tag': ['LOC', 'LOC', 'nz', 'v', 'n', 'v', 'm', 'v']},
#  {'word': ['河南', '山东', '等', '10', '省份', '有', '大', '到', '暴雨'],
#   'tag': ['LOC', 'LOC', 'u', 'm', 'n', 'v', 'a', 'v', 'n']},
#  {'word': ['法定节假日', '时间', '分布', '格局', '将', '优化'],
#   'tag': ['nz', 'n', 'vn', 'n', 'd', 'v']},
#  {'word': ['泳池', '事故', '死者', '母亲', '：', '救', '别人', '却', '没救', '儿子'],
#   'tag': ['n', 'n', 'n', 'n', 'w', 'v', 'r', 'd', 'v', 'n']},
#  {'word': ['泽连斯基', '：', '正', '调查', '651起', '官员', '通', '敌案'],
#   'tag': ['PER', 'w', 'd', 'v', 'm', 'n', 'v', 'n']},
#  {'word': ['海南', '12名', '乘客', '海钓', '时', '船只', '爆炸'],
#   'tag': ['LOC', 'm', 'n', 'n', 'n', 'n', 'v']},
#  {'word': ['海南', '海钓', '船', '只', '爆炸', ' ', '乘客', '坐', '橡皮艇', '逃生'],
#   'tag': ['LOC', 'n', 'n', 'd', 'v', 'w', 'n', 'v', 'n', 'v']},
#  {'word': ['深圳交警回应美团', '骑手', '被', '车', '连撞', '两次'],
#   'tag': ['ORG', 'n', 'p', 'n', 'v', 'm']},
#  {'word': ['父亲', '与', '罕见', '病儿', '坦然', '面对', '生命', '倒计时'],
#   'tag': ['n', 'p', 'a', 'n', 'ad', 'v', 'n', 'n']},
#  {'word': ['爷爷', '微信', '打字', '要钱', '孙子', '果断', '报警'],
#   'tag': ['n', 'nz', 'v', 'v', 'n', 'ad', 'v']},
#  {'word': ['爸爸', '带', '儿子', '参观', '浙大', '8年后', '儿子', '考入'],
#   'tag': ['n', 'v', 'n', 'v', 'ORG', 'TIME', 'n', 'v']},
#  {'word': ['理想', 'L9', '空气', '悬架', '为何', '如此', '脆弱'],
#   'tag': ['n', 'nz', 'n', 'n', 'r', 'r', 'a']},
#  {'word': ['甘肃', '今日0-12时', '新增', '本土', '“', '14', '+', '104', '”'],
#   'tag': ['LOC', 'TIME', 'v', 'n', 'w', 'm', 'w', 'm', 'w']},
#  {'word': ['甘肃', '昨', '增', '本土', '32', '+', '199例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['电影', '《', '人生大事', '》', '密钥', '延期'],
#   'tag': ['n', 'w', 'nw', 'w', 'n', 'v']},
#  {'word': ['男子', '健身房', '洗澡', '被', '女子', '看光', '向', '店家', '索赔'],
#   'tag': ['n', 'n', 'v', 'p', 'n', 'v', 'p', 'n', 'v']},
#  {'word': ['男子', '连', '喝', '48瓶', '藿香', '正气', '水', '开车', '被', '抓'],
#   'tag': ['n', 'd', 'v', 'm', 'n', 'n', 'n', 'v', 'p', 'v']},
#  {'word': ['男子', '钓', '20多斤', '大鱼', '在', '小区', '转', '三圈', '炫耀'],
#   'tag': ['n', 'v', 'm', 'n', 'p', 'n', 'v', 'm', 'v']},
#  {'word': ['男子', '霸占', '医院', '病房', '近三年', '被拘留'],
#   'tag': ['n', 'v', 'n', 'n', 'TIME', 'v']},
#  {'word': ['男子', '骑', '二八', '大杠', '参加', '40公里', '自行车赛'],
#   'tag': ['n', 'v', 'm', 'n', 'v', 'm', 'n']},
#  {'word': ['疑', '因', '蚊香', '引发', '火灾', ' ', '湖南', '12', '头牛', '被', '烧死'],
#   'tag': ['v', 'p', 'n', 'v', 'n', 'w', 'LOC', 'm', 'n', 'p', 'v']},
#  {'word': ['直击', '现场', '：', '天津', '居民楼', '燃', '爆', '10', '人', '受伤'],
#   'tag': ['v', 's', 'w', 'LOC', 'n', 'v', 'v', 'm', 'n', 'v']},
#  {'word': ['直击', '现场', '：', '天津', '居民楼', '燃', '爆', '8', '人', '受伤'],
#   'tag': ['v', 's', 'w', 'LOC', 'n', 'v', 'v', 'm', 'n', 'v']},
#  {'word': ['知名', '学者', '陈春花', '博士', '文凭', '被', '质疑'],
#   'tag': ['a', 'n', 'PER', 'n', 'n', 'p', 'v']},
#  {'word': ['福建卫健委', '主任', '黄如欣', '任', '三明', '市委书记'],
#   'tag': ['ORG', 'n', 'PER', 'v', 'ns', 'n']},
#  {'word': ['章公', '祖师', '肉身', '坐', '佛像', '追索案', '维持', '原判'],
#   'tag': ['PER', 'n', 'n', 'v', 'n', 'n', 'v', 'n']},
#  {'word': ['第一届', '青龙', '电视剧', '大赏', '获奖', '名单'],
#   'tag': ['m', 'n', 'n', 'n', 'vn', 'n']},
#  {'word': ['索马里', '一', '客机', '降落', '时', '“', '倒扣', '”', '在', '机场'],
#   'tag': ['LOC', 'm', 'n', 'v', 'n', 'w', 'n', 'w', 'p', 'n']},
#  {'word': ['索马里', '客机', '降落', '时', '倾覆', ' ', '现场', '浓烟', '滚滚'],
#   'tag': ['LOC', 'n', 'v', 'n', 'v', 'w', 's', 'n', 'a']},
#  {'word': ['纽约', '一天内', '12', '人', '遭枪击', '2', '人', '被捅', '伤'],
#   'tag': ['LOC', 'TIME', 'm', 'n', 'v', 'm', 'n', 'v', 'v']},
#  {'word': ['经济学人', '杂志', '涉', '安倍', '评论', '文章', '引争议'],
#   'tag': ['n', 'n', 'v', 'PER', 'v', 'n', 'v']},
#  {'word': ['网', '传', '女子', '被', '男子', '拽', '着', '头发', '拖', '进', '卫生间'],
#   'tag': ['n', 'v', 'n', 'p', 'n', 'v', 'u', 'n', 'v', 'v', 'n']},
#  {'word': ['美乌', '两国', '第一夫人', '将', '在', '白宫', '见面'],
#   'tag': ['nz', 'n', 'n', 'd', 'p', 'ns', 'v']},
#  {'word': ['美', '再次', '对', '台', '军售', ' ', '为何', '总是', '言行', '不', '一'],
#   'tag': ['an', 'd', 'p', 'ns', 'n', 'w', 'r', 'd', 'v', 'd', 'a']},
#  {'word': ['美国', '为何', '害怕', '俄罗斯', '购买', '伊朗', '无人机'],
#   'tag': ['LOC', 'r', 'v', 'LOC', 'v', 'LOC', 'n']},
#  {'word': ['美国务卿会见泽连斯基夫人'], 'tag': ['ORG']},
#  {'word': ['美国务院', '：', '仍', '继续', '坚持', '一个', '中国', '政策'],
#   'tag': ['ORG', 'w', 'd', 'vd', 'v', 'm', 'LOC', 'n']},
#  {'word': ['美国', '套用', '俄', '乌', '经验', '改变', '对', '台', '军售', '思路'],
# ...
#   'tag': ['t', 'd', 'v', 'n', 'v', 'n', 'n']},
#  {'word': ['从', '六', '楼', '坠落', '的', '女孩', '欣欣', '身体', '已', '无碍'],
#   'tag': ['p', 'm', 'n', 'v', 'u', 'n', 'nr', 'n', 'd', 'v']},
#  {'word': ['从', '考古', '文化', '遗存', '看', '上海', '古代', '文明'],
#   'tag': ['p', 'vn', 'n', 'vn', 'v', 'LOC', 't', 'n']},
#  {'word': ['任', '上', '被查', '公安局长', '曾', '在', '王立科', '手下', '收钱'],
#   'tag': ['v', 'f', 'v', 'n', 'd', 'p', 'PER', 's', 'v']},
#  {'word': ['伦敦', '高温', '持续', '宣布', '进入', '重大', '事件', '状态'],
#   'tag': ['LOC', 'n', 'vd', 'v', 'v', 'a', 'n', 'n']},
#  {'word': ['佩洛西', '丈夫', '提前', '购入', '芯片股', '引质疑'],
#   'tag': ['PER', 'n', 'vd', 'v', 'n', 'v']},
#  {'word': ['俄', '两架', '图', '-', '160', '轰炸机', '在', '巴伦支海', '飞行'],
#   'tag': ['LOC', 'm', 'n', 'w', 'm', 'n', 'p', 'LOC', 'v']},
#  {'word': ['俄军', '后勤', '专列', '首次', '公开', '：', '可', '洗衣', '洗澡'],
#   'tag': ['n', 'n', 'n', 'm', 'v', 'w', 'v', 'v', 'v']},
#  {'word': ['俄国', '防部', '展示', '“', '洗浴列车', '”'],
#   'tag': ['LOC', 'n', 'v', 'w', 'nz', 'w']},
#  {'word': ['俄', '外长', '：', '在', '乌', '军事', '行动', '地理', '目标', '扩大'],
#   'tag': ['LOC', 'n', 'w', 'p', 'ns', 'n', 'n', 'n', 'n', 'v']},
#  {'word': ['俄', '外长', '：', '现在', '与', '乌和谈', '没有', '任何', '意义'],
#   'tag': ['LOC', 'n', 'w', 'TIME', 'p', 'nz', 'v', 'r', 'n']},
#  {'word': ['俄', '称', '打击', '乌方', '美制', '鱼叉', '导弹', '系统'],
#   'tag': ['LOC', 'v', 'v', 'n', 'v', 'n', 'n', 'n']},
#  {'word': ['儿子', '考上', '重点', ' ', '粉', '店', '挂', '横幅', '霸气', '打折'],
#   'tag': ['n', 'v', 'n', 'w', 'n', 'n', 'v', 'n', 'n', 'v']},
#  {'word': ['冯彬', '夺', '田径', '世锦赛', '女子', '铁饼', '金牌'],
#   'tag': ['PER', 'v', 'n', 'nz', 'n', 'n', 'n']},
#  {'word': ['冷眼', '看', '抗议', '民众', '被架', '离', ' ', '陈时中', '挨批'],
#   'tag': ['n', 'v', 'vn', 'n', 'n', 'v', 'w', 'PER', 'v']},
#  {'word': ['刘畊宏', '说', 'vivi', '是', '最', '难', '带', '的', '学员'],
#   'tag': ['PER', 'v', 'nz', 'v', 'd', 'a', 'v', 'u', 'n']},
#  {'word': ['刘诗颖', '晋级', '世锦赛', '女子', '标枪', '决赛'],
#   'tag': ['PER', 'v', 'nz', 'n', 'n', 'n']},
#  {'word': ['北京16区', '全部', '开展', '教师', '轮岗'],
#   'tag': ['LOC', 'n', 'v', 'n', 'v']},
#  {'word': ['北京金饰品', '价格', '每', '克', '再', '降', '5元'],
#   'tag': ['ORG', 'n', 'r', 'q', 'd', 'v', 'm']},
#  {'word': ['北半球', '最', '冷', '之', '地', '每天', '融冰', '60亿吨'],
#   'tag': ['n', 'd', 'a', 'u', 'n', 'TIME', 'v', 'm']},
#  {'word': ['医药', '经销商', '称', '抗癌药', '价格', '还', '不如', '雪糕'],
#   'tag': ['n', 'n', 'v', 'nz', 'n', 'd', 'v', 'n']},
#  {'word': ['华为', '斥资', '1900万', '在', '昆明', '拿', '20亩', '地'],
#   'tag': ['ORG', 'v', 'm', 'p', 'LOC', 'v', 'm', 'n']},
#  {'word': ['南方', '共同', '市场', '峰会', '拒绝', '泽连斯基', '讲话'],
#   'tag': ['s', 'a', 'n', 'n', 'v', 'PER', 'v']},
#  {'word': ['卧底', '必胜客', '：', '烹', '炸油', '十天', '一', '换', '墨', '一样', '黑'],
#   'tag': ['n', 'ORG', 'w', 'v', 'nz', 'TIME', 'm', 'v', 'n', 'a', 'a']},
#  {'word': ['印度', '“', '高考', '”', '安检', '强迫', '女生', '脱', '内衣'],
#   'tag': ['LOC', 'w', 'n', 'w', 'n', 'v', 'n', 'v', 'n']},
#  {'word': ['印度尼西亚', '总统', '佐科', '将', '访华'],
#   'tag': ['LOC', 'n', 'PER', 'd', 'v']},
#  {'word': ['印度', '海军', '航母', '超日', '王号', '发生', '火灾'],
#   'tag': ['LOC', 'n', 'n', 'v', 'n', 'v', 'n']},
#  {'word': ['印度', '第二位', '女', '总统', '有', '何', '来历'],
#   'tag': ['LOC', 'm', 'a', 'n', 'v', 'r', 'n']},
#  {'word': ['去年', '卫生', '总', '费用', '7.5万亿', ' ', '花', '在', '哪里', '了'],
#   'tag': ['TIME', 'n', 'a', 'n', 'm', 'w', 'v', 'p', 'r', 'xc']},
#  {'word': ['取消', '预售', '制', '到底', '难', '在', '哪', '？'],
#   'tag': ['v', 'vn', 'n', 'd', 'a', 'p', 'r', 'w']},
#  {'word': ['叙利亚', '宣布', '与', '乌克兰', '断交'],
#   'tag': ['LOC', 'v', 'p', 'LOC', 'v']},
#  {'word': ['台军', '保养', '坦克', '出', '意外', '2', '人', '被', '炮管', '重击'],
#   'tag': ['n', 'v', 'n', 'v', 'n', 'm', 'n', 'p', 'v', 'v']},
#  {'word': ['台', '媒体', '人', '揭捷克89人团', '赴台', '真相'],
#   'tag': ['n', 'n', 'n', 'ORG', 'v', 'n']},
#  {'word': ['台媒', '再次', '炒作', '大陆', '航母', '疑', '现身', '台海'],
#   'tag': ['n', 'd', 'v', 'ns', 'n', 'v', 'v', 'LOC']},
#  {'word': ['台媒', '：', '佩洛西', '企图', '窜访', '台湾', '意在', '选票'],
#   'tag': ['n', 'w', 'PER', 'v', 'v', 'LOC', 'v', 'n']},
#  {'word': ['台湾', '媒体', '人', '喊话', '佩洛西', '：', '不', '欢迎', '你', '来'],
#   'tag': ['LOC', 'n', 'n', 'v', 'PER', 'w', 'd', 'v', 'r', 'v']},
#  {'word': ['司机', '等', '红灯', '时', '看', '手机', '被', '罚', '200元'],
#   'tag': ['n', 'u', 'n', 'n', 'v', 'n', 'p', 'v', 'm']},
#  {'word': ['名记', '：', '国王', '底薪', '签', '下', '奇马·莫尼克'],
#   'tag': ['n', 'w', 'n', 'n', 'v', 'v', 'PER']},
#  {'word': ['向', '中国', '驻', '里约', '领馆', '投', '爆炸物', '嫌犯', '被捕'],
#   'tag': ['p', 'LOC', 'v', 'LOC', 'n', 'v', 'n', 'n', 'v']},
#  {'word': ['周鹏', '：', '竞技', '体育', '残酷性', '在于', '只', '论', '输赢'],
#   'tag': ['PER', 'w', 'vn', 'n', 'n', 'v', 'd', 'v', 'n']},
#  {'word': ['哈尔滨一小区', '清晨', '发生', '爆炸', '有人', '受伤'],
#   'tag': ['LOC', 'TIME', 'v', 'vn', 'r', 'v']},
#  {'word': ['哈梅内伊', '：', '北约', '早晚', '会', '发起', '战争'],
#   'tag': ['PER', 'w', 'ORG', 't', 'v', 'v', 'n']},
#  {'word': ['哈登', '两年', '6860万', '续约', '76', '人'],
#   'tag': ['PER', 'TIME', 'm', 'n', 'm', 'n']},
#  {'word': ['四川', '一', '尼姑', '举报', '和尚', '骚扰', ' ', '警方', '通报'],
#   'tag': ['LOC', 'm', 'n', 'v', 'n', 'v', 'w', 'n', 'v']},
#  {'word': ['四川', '昨', '增', '本土', '16', '+', '28例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['四川', '警方', '回应', '“', '网民', '举报', '被', '骚扰', '恐吓', '”'],
#   'tag': ['LOC', 'n', 'v', 'w', 'n', 'v', 'p', 'v', 'v', 'w']},
#  {'word': ['国内', '高端', '火车', '游', '热度', '增高'],
#   'tag': ['s', 'n', 'n', 'v', 'n', 'v']},
#  {'word': ['国台办', '批', '欧洲', '议会', '副议长', '窜访', '台湾'],
#   'tag': ['ORG', 'v', 'LOC', 'n', 'n', 'v', 'LOC']},
#  {'word': ['国家卫健委', '：', '全国', '防疫', '形势', '严峻', '复杂'],
#   'tag': ['ORG', 'w', 'n', 'vn', 'n', 'a', 'a']},
#  {'word': ['埃尔多安', '称', '北欧', '已', '成', '恐怖主义', '巢穴'],
#   'tag': ['PER', 'v', 'LOC', 'd', 'v', 'nz', 'n']},
#  {'word': ['埃尔多', '安让', '普京', '等', '了', '近一分钟'],
#   'tag': ['PER', 'v', 'PER', 'v', 'u', 'TIME']},
#  {'word': ['基辛格', '劝', '拜登', '不要', '与', '中国', '无休止', '对抗'],
#   'tag': ['PER', 'v', 'nr', 'v', 'p', 'LOC', 'v', 'vn']},
#  {'word': ['塔克', '29', '+', '6', ' ', '约旦', '胜', '伊朗', '进', '亚洲', '杯', '四强'],
#   'tag': ['nr', 'm', 'w', 'm', 'w', 'd', 'v', 'LOC', 'v', 'LOC', 'n', 'n']},
#  {'word': ['复垦', '归田', ' ', '粮食', '生态', '双', '“', '丰收', '”'],
#   'tag': ['v', 'v', 'w', 'n', 'n', 'm', 'w', 'vn', 'w']},
#  {'word': ['外交部', '回应', 'CIA', '局长', '涉', '台湾', '问题', '言论'],
#   'tag': ['nt', 'v', 'nz', 'n', 'v', 'LOC', 'n', 'n']},
#  {'word': ['外交部', '回应', '美高官涉华', '言论'], 'tag': ['nt', 'v', 'ns', 'n']},
#  {'word': ['外交部', '：', '如', '佩洛西', '访台', '中方', '必将', '反制'],
#   'tag': ['nt', 'w', 'v', 'PER', 'v', 'n', 'd', 'v']},
#  {'word': ['外卖员', '因', '电梯', '误时', '殴打', '同', '乘', '业主'],
#   'tag': ['n', 'p', 'n', 'd', 'v', 'd', 'v', 'n']},
#  {'word': ['多', '人', '死于', '热射病', ' ', '背后', '折射', '哪些', '问题'],
#   'tag': ['a', 'n', 'v', 'nz', 'w', 's', 'v', 'r', 'n']},
#  {'word': ['大', '二', '男生', '2.8万', '购', '三金', '被', '套路'],
#   'tag': ['a', 'm', 'n', 'm', 'v', 'n', 'p', 'n']},
#  {'word': ['大妈', '买菜', '时', '偷走', '摊主', '整', '筐', '硬币'],
#   'tag': ['n', 'v', 'n', 'v', 'n', 'a', 'n', 'n']},
#  {'word': ['天津', '开展', '新一轮', '全员', '核检', '筛查'],
#   'tag': ['LOC', 'v', 'm', 'n', 'vn', 'vn']},
#  {'word': ['央媒', '评引', '进', '菲律宾', '博士', '：', '钱', '去', '哪', '了'],
#   'tag': ['n', 'v', 'v', 'LOC', 'n', 'w', 'n', 'v', 'r', 'xc']},
#  {'word': ['奥密克戎变异株', '引发', '全球', '疫情', '反弹'],
#   'tag': ['nz', 'v', 'n', 'n', 'v']},
#  {'word': ['女子', '36岁', '当', '奶奶', ' ', '民政局', '回应'],
#   'tag': ['n', 'm', 'v', 'n', 'w', 'ORG', 'v']},
#  {'word': ['女子', '吐槽', '生', '了', '5胎', '老公', '还', '想', '生'],
#   'tag': ['n', 'v', 'v', 'u', 'm', 'n', 'd', 'v', 'v']},
#  {'word': ['女子', '带', '儿子', '回娘家', '伪装', '路人', '偶遇'],
#   'tag': ['n', 'v', 'n', 'v', 'v', 'n', 'v']},
#  {'word': ['女子', '晒', '退伍', '公公', '种', '的', '西瓜'],
#   'tag': ['n', 'v', 'vn', 'n', 'v', 'u', 'n']},
#  {'word': ['女子', '等', '红灯', '引', '旁车', '男子', '频频', '侧目'],
#   'tag': ['n', 'u', 'n', 'v', 'n', 'n', 'd', 'v']},
#  {'word': ['女子', '等', '红灯', '玩', '手机', '被', '罚', '200元'],
#   'tag': ['n', 'u', 'n', 'v', 'n', 'p', 'v', 'm']},
#  {'word': ['女子', '见', '网友', '被', '“', '鸽', '”', ' ', '报', '假警', '泄愤'],
#   'tag': ['n', 'v', 'n', 'p', 'w', 'n', 'w', 'w', 'v', 'n', 'v']},
#  {'word': ['女子', '见', '网友', '被', '鸽', ' ', '报', '假警', '泄愤'],
#   'tag': ['n', 'v', 'n', 'p', 'n', 'w', 'v', 'n', 'v']},
#  {'word': ['女子', '见', '网友', '被', '鸽', ' ', '报警', '称', '有人', '卖淫'],
#   'tag': ['n', 'v', 'n', 'p', 'n', 'w', 'v', 'v', 'r', 'v']},
#  {'word': ['女子', '订婚宴', '照片', '被', '谣传', '为', '会所', '技师'],
#   'tag': ['n', 'n', 'n', 'p', 'v', 'v', 'n', 'n']},
#  {'word': ['好心人', '徒手', '接住', '楼上', '坠落', '的', '幼童'],
#   'tag': ['n', 'd', 'v', 's', 'v', 'u', 'n']},
#  {'word': ['如何', '看待', '《', '沉香如屑', '》', '评论', '两极化'],
#   'tag': ['r', 'v', 'w', 'nw', 'w', 'v', 'vn']},
#  {'word': ['如何', '解读', '俄', '外长', '称', '战争', '不再', '局限', '乌东'],
#   'tag': ['r', 'v', 'LOC', 'n', 'v', 'n', 'd', 'v', 'PER']},
#  {'word': ['媒体', '评', '女生', '卫生间', '遭', '拖拽', '：', '零', '容忍'],
#   'tag': ['n', 'v', 'n', 'n', 'v', 'vn', 'w', 'm', 'vn']},
#  {'word': ['媒体', '评', '必胜客', '“', '塌房', '”', '：', '别', '只', '表面', '功夫'],
#   'tag': ['n', 'v', 'ORG', 'w', 'vn', 'w', 'w', 'a', 'q', 'n', 'n']},
#  {'word': ['媒体', '：', '“', '厕所', '拖拽', '事件', '”', '双方', '非', '情侣'],
#   'tag': ['n', 'w', 'w', 'n', 'v', 'n', 'w', 'n', 'v', 'n']},
#  {'word': ['媒体', '：', '张小泉', '“', '失', '蒜', '”'],
#   'tag': ['n', 'w', 'PER', 'w', 'v', 'n', 'w']},
#  {'word': ['媒体', '：', '拖拽', '女生', '男子', '涉嫌', '猥亵罪', '被刑拘'],
#   'tag': ['n', 'w', 'v', 'n', 'n', 'v', 'n', 'v']},
#  {'word': ['孙铭徽', '战', '黎巴嫩', '全场', '6分', '7次', '失误'],
#   'tag': ['PER', 'v', 'LOC', 'n', 'm', 'm', 'vn']},
#  {'word': ['宁夏', '初', '判', '鼠疫', '患者', '在', '自然', '疫源', '地', '感染'],
#   'tag': ['LOC', 'd', 'v', 'n', 'n', 'p', 'a', 'n', 'u', 'v']},
#  {'word': ['宁夏', '：', '对', '鼠疫', '涉疫', '区域', '人员', '分类', '管控'],
#   'tag': ['LOC', 'w', 'p', 'n', 'vn', 'n', 'n', 'vn', 'vn']},
#  {'word': ['宁波', '通报', '多', '人', '打', '砸', '烧烤', '店', '：', '4', '人', '被拘'],
#   'tag': ['LOC', 'v', 'a', 'n', 'v', 'v', 'vn', 'n', 'w', 'm', 'n', 'v']},
#  {'word': ['安徽',
#    '一',
#    '公交',
#    '失控',
#    '与',
#    '多',
#    '车',
#    '相撞',
#    '致',
#    '2',
#    '死',
#    '5',
#    '伤'],
#   'tag': ['LOC', 'm', 'n', 'v', 'p', 'a', 'n', 'v', 'v', 'm', 'v', 'm', 'n']},
#  {'word': ['安徽', '亳州', '一家', '四兄弟', '同上', '军校'],
#   'tag': ['ns', 'LOC', 'm', 'n', 'v', 'n']},
#  {'word': ['安徽', '昨', '增', '本土', '7', '+', '77例', '：', '蚌埠', '7', '+', '68例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm', 'w', 'LOC', 'm', 'w', 'm']},
#  {'word': ['安徽', '蚌埠', '：', '将', '对', '5', '-', '10万', '客户', '本金', '垫付'],
#   'tag': ['LOC', 'LOC', 'w', 'd', 'p', 'm', 'w', 'm', 'n', 'n', 'v']},
#  {'word': ['官方', '：', '5万', '以下', '登记', '客户', '基本', '垫付', '完毕'],
#   'tag': ['n', 'w', 'm', 'f', 'v', 'n', 'd', 'v', 'v']},
#  {'word': ['官方', '：', '低风险', '区', '人员', '离开', '应持', '核酸', '证明'],
#   'tag': ['n', 'w', 'n', 'n', 'n', 'v', 'v', 'n', 'n']},
#  {'word': ['官方', '：', '重点', '打击', '掏空', '中小银行', '的', '股东'],
#   'tag': ['n', 'w', 'd', 'v', 'v', 'ORG', 'u', 'n']},
#  {'word': ['实拍', '青海', '沙尘暴', ' ', '巨大', '沙墙', '遮天蔽日'],
#   'tag': ['v', 'LOC', 'n', 'w', 'a', 'LOC', 'v']},
#  {'word': ['小区', '池塘', '发现', '2亿年前', '远古生物'],
#   'tag': ['n', 'n', 'v', 'TIME', 'n']},
#  {'word': ['小姨', '定制', '自己', '照片', '衣服', '给', '外甥', '穿'],
#   'tag': ['PER', 'v', 'r', 'n', 'n', 'p', 'n', 'v']},
#  {'word': ['山东省委', '副', '秘书长', '江成', '任', '山东省', '领导'],
#   'tag': ['ORG', 'a', 'n', 'PER', 'v', 'LOC', 'n']},
#  {'word': ['山西', '多名', '公安局长', '转任', '高校', '副校长'],
#   'tag': ['LOC', 'm', 'n', 'v', 'n', 'n']},
#  {'word': ['工人', '安装', '路灯', '从', '数十米', '高空', '坠亡'],
#   'tag': ['n', 'v', 'n', 'p', 'm', 'n', 'v']},
#  {'word': ['工信部', '“', '一', '证', '通查', '2.0', '”', '上线'],
#   'tag': ['ORG', 'w', 'm', 'n', 'v', 'm', 'w', 'v']},
#  {'word': ['市场', '监管', '突击', '检查', '必胜客'],
#   'tag': ['n', 'vn', 'vn', 'vn', 'ORG']},
#  {'word': ['广东', '惠州', '3', '车', '追尾', '致', '5', '死'],
#   'tag': ['LOC', 'LOC', 'm', 'n', 'v', 'v', 'm', 'v']},
#  {'word': ['广汽', '曾庆洪', '笑', '称为', '宁德时代', '“', '打工', '”'],
#   'tag': ['ORG', 'PER', 'v', 'v', 'ORG', 'w', 'v', 'w']},
#  {'word': ['广西', '昨', '增', '本土', '52', '+', '135例'],
#   'tag': ['LOC', 't', 'v', 'n', 'm', 'w', 'm']},
#  {'word': ['张同学', '想', '拍', '出', '周星驰', '电影', '里', '的', '故事'],
#   'tag': ['PER', 'v', 'v', 'v', 'PER', 'n', 'f', 'u', 'n']},
#  {'word': ['张同学', '：', '要', '把', '鸡毛蒜皮', '拍', '到', '极致'],
#   'tag': ['PER', 'w', 'v', 'p', 'n', 'v', 'v', 'n']},
#  {'word': ['张小泉', '分店', '店员', '：', '拍', '蒜', '习惯', '可', '改'],
#   'tag': ['PER', 'n', 'n', 'w', 'v', 'n', 'n', 'v', 'v']},
#  {'word': ['徐工机械', '：', '将', '于', '8月1日', '开始', '停牌'],
#   'tag': ['ORG', 'w', 'd', 'p', 'TIME', 'v', 'vn']},
#  {'word': ['徐杰战黎巴嫩末节连中3记', '关键', '三分'], 'tag': ['nw', 'a', 'm']},
#  {'word': ['徒手', '接人', '男子', '女儿', '与', '坠楼', '女童', '同名'],
#   'tag': ['d', 'v', 'n', 'n', 'c', 'v', 'n', 'v']},
#  {'word': ['徒手', '接', '女童', '的', '好心人', '找到', '了'],
#   'tag': ['d', 'v', 'n', 'u', 'n', 'v', 'xc']},
#  {'word': ['微信', '更新', '：', '可', '在', '横幅', '中', '查看', '回复', '消息'],
#   'tag': ['nz', 'v', 'w', 'v', 'p', 'n', 'f', 'v', 'v', 'n']},
#  {'word': ['德国', '期望', '北溪', '-', '1', '管道', '按时', '恢复', '供气'],
#   'tag': ['LOC', 'v', 'ns', 'w', 'm', 'n', 'd', 'v', 'vn']},
#  {'word': ['德国', '防长', '：', '已', '无', '多余', '库存', '武器', '可', '援', '乌'],
#   'tag': ['LOC', 'n', 'w', 'd', 'v', 'a', 'n', 'n', 'v', 'v', 'a']},
#  {'word': ['必胜客', '员工', '面对', '执法', '现场', '倒', '原料'],
#   'tag': ['ORG', 'n', 'v', 'vn', 's', 'v', 'n']},
#  {'word': ['急需', '转运', '的', '6岁', '女童', '已', '到', '医院'],
#   'tag': ['v', 'vn', 'u', 'm', 'n', 'd', 'v', 'n']},
#  {'word': ['恒大汽车', '：', '恒驰', '5', '订单', '数量', '超', '3.7万辆'],
#   'tag': ['ORG', 'w', 'nz', 'm', 'n', 'n', 'v', 'm']},
#  {'word': ['意总理德拉吉', '赢得', '参议院', '信任', '投票'],
#   'tag': ['PER', 'v', 'n', 'vn', 'vn']},
#  {'word': ['成都', '一', '男子', '坠亡', ' ', '警方', '：', '因', '琐事', '轻生'],
#   'tag': ['LOC', 'm', 'n', 'v', 'w', 'n', 'w', 'p', 'n', 'v']},
#  {'word': ['成都', '汽车', '喷纳粹', '标志', '的', '车主', '已', '找到'],
#   'tag': ['LOC', 'n', 'nz', 'n', 'u', 'n', 'd', 'v']},
#  {'word': ['成都', '男子', '在', '商场', '掐死', '女友', '？', '民警', '回应'],
#   'tag': ['LOC', 'n', 'p', 'n', 'v', 'n', 'w', 'n', 'v']},
#  {'word': ['成都', '男子', '在', '商场', '掐死', '女友', '？', '警方', '回应'],
#   'tag': ['LOC', 'n', 'p', 'n', 'v', 'n', 'w', 'n', 'v']},
#  {'word': ['我', '国', '将', '迎来', '史', '上', '最大', '退休潮'],
#   'tag': ['r', 'n', 'd', 'v', 'n', 'f', 'a', 'n']},
#  {'word': ['扎波罗热核电站', '遭', '无人机', '袭击'], 'tag': ['nz', 'v', 'n', 'v']},
#  {'word': ['扎波罗热核电站', '遭袭', ' ', '机组', '未', '受损'],
#   'tag': ['nz', 'v', 'w', 'n', 'd', 'v']},
#  {'word': ['拜登', '将', '与', '中国', '领导人', '通话', '？', '中方', '回应'],
#   'tag': ['PER', 'd', 'p', 'LOC', 'n', 'v', 'w', 'n', 'v']},
#  {'word': ['拜登', '演讲', '时', '自称', '患癌', ' ', '白宫', '紧急', '澄清'],
#   'tag': ['PER', 'v', 'n', 'v', 'vn', 'w', 'n', 'ad', 'v']},
#  {'word': ['拜登', '谈', '“', '佩洛西', '将', '访台', '”', '：', '军方', '担忧'],
#   'tag': ['PER', 'v', 'w', 'PER', 'p', 'n', 'w', 'w', 'n', 'v']},
#  {'word': ['教师', '轮岗', '来了', ' ', '学区', '房', '还能', '买', '吗'],
#   'tag': ['n', 'v', 'v', 'w', 'n', 'n', 'v', 'v', 'xc']},
#  {'word': ['教育', '专家', '评', '北京16区', '教师', '轮岗'],
#   'tag': ['vn', 'n', 'v', 'LOC', 'n', 'v']},
#  {'word': ['斯里兰卡', '经济', '哪里', '出', '问题', '了'],
#   'tag': ['LOC', 'n', 'r', 'v', 'n', 'xc']},
#  {'word': ['日媒', '：', '安倍', '“', '国葬', '”', '拟', '于', '9月27日', '举行'],
#   'tag': ['n', 'w', 'PER', 'w', 'n', 'w', 'v', 'p', 'TIME', 'v']},
#  {'word': ['日本', '购买', '有史以来', '最', '贵', '天然气'],
#   'tag': ['LOC', 'v', 'd', 'd', 'a', 'n']},
#  {'word': ['易烊千玺', '同时', '提名', '百花奖', '男', '主', '男', '配'],
#   'tag': ['PER', 'd', 'v', 'nz', 'a', 'n', 'n', 'v']},
#  {'word': ['普京', '回应', '欧洲', '“', '气', '荒', '”', '：', '与', '俄', '无关'],
#   'tag': ['PER', 'v', 'LOC', 'w', 'n', 'a', 'w', 'w', 'p', 'LOC', 'v']},
#  {'word': ['普京', '抵达', '伊朗', ' ', '保镖', '提', '黑色', '箱子', '紧随'],
#   'tag': ['PER', 'v', 'LOC', 'w', 'n', 'v', 'n', 'n', 'v']},
#  {'word': ['普京', '称', '北溪', '管道', '将', '恢复', '向', '欧洲', '供气'],
#   'tag': ['PER', 'v', 'ns', 'n', 'd', 'v', 'p', 'LOC', 'v']},
#  {'word': ['普京', '称', '美军', '必须', '停止', '抢劫', '叙利亚'],
#   'tag': ['PER', 'v', 'n', 'd', 'v', 'vn', 'LOC']},
#  {'word': ['普京', '：', '西方', '的', '优势', '地位', '主要', '来自', '抢劫'],
#   'tag': ['PER', 'w', 's', 'u', 'n', 'n', 'ad', 'v', 'vn']},
#  {'word': ['曝', 'iPhone', ' ', '15', '全', '系', '叹', '号屏'],
#   'tag': ['v', 'nz', 'w', 'm', 'a', 'n', 'v', 'n']},
#  {'word': ['曝', '德云社', '张九南', '暂停', '演出'],
#   'tag': ['v', 'ORG', 'PER', 'v', 'vn']},
#  ...]

# %%
len(titles), len(set(titles))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-081b16a6f7d1> in <module>
# ----> 1 len(titles), len(set(titles))
#
# TypeError: unhashable type: 'dict'

# %%
import tempfile

output_dir = tempfile.mkdtemp()
original_dim = tf_hub.load(model_url)(['']).shape[1]
random_projection_matrix = None

if projected_dim:
  random_projection_matrix = generate_random_projection_weights(
      original_dim, projected_dim)

args = {
    'job_name': 'hub2emb-{}'.format(datetime.utcnow().strftime('%y%m%d-%H%M%S')),
    'runner': 'DirectRunner',
    'batch_size': 1024,
    'data_dir': 'text.txt',
    'output_dir': output_dir,
    'model_url': model_url,
    'random_projection_matrix': random_projection_matrix,
}

print("Pipeline args are set.")
args
# Out:
# A Gaussian random weight matrix was creates with shape of (128, 64)
# Storing random projection matrix to disk...
# Pipeline args are set.
# {'job_name': 'hub2emb-220726-054615',
#  'runner': 'DirectRunner',
#  'batch_size': 1024,
#  'data_dir': 'text.txt',
#  'output_dir': 'C:\\Users\\helix\\AppData\\Local\\Temp\\tmpd9yajptw',
#  'model_url': 'C:\\Users\\helix\\Downloads\\nnlm-zh-dim128_2',
#  'random_projection_matrix': array([[-0.04742824,  0.06190167, -0.23076671, ...,  0.02917528,
#          -0.25928597, -0.08259265],
#         [ 0.04793924,  0.11276546, -0.22449292, ..., -0.06111532,
#           0.02767367,  0.17275463],
#         [-0.05708836,  0.23229133,  0.07621995, ..., -0.35139933,
#           0.10296169,  0.19293363],
#         ...,
#         [-0.1453888 ,  0.04595867,  0.04800978, ..., -0.11849089,
#          -0.06036516, -0.16451824],
#         [ 0.03487392, -0.03669805,  0.06545562, ..., -0.05750089,
#           0.05918353, -0.08098674],
#         [-0.09450219,  0.06656731,  0.13598591, ..., -0.04341026,
#          -0.03367222,  0.26572768]])}

# %%
print("Running pipeline...")
# %time run_hub2emb(args)
print("Pipeline is done.")
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# Running pipeline...
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', 'C:\\Users\\helix\\AppData\\Roaming\\jupyter\\runtime\\kernel-51569d6a-4a08-470e-b708-aec8beffc1a8.json']
# WARNING:apache_beam.options.pipeline_options:Discarding invalid overrides: {'batch_size': 1024, 'data_dir': 'text.txt', 'output_dir': 'C:\\Users\\helix\\AppData\\Local\\Temp\\tmpd9yajptw', 'model_url': 'C:\\Users\\helix\\Downloads\\nnlm-zh-dim128_2', 'random_projection_matrix': array([[-0.04742824,  0.06190167, -0.23076671, ...,  0.02917528,
#         -0.25928597, -0.08259265],
#        [ 0.04793924,  0.11276546, -0.22449292, ..., -0.06111532,
#          0.02767367,  0.17275463],
#        [-0.05708836,  0.23229133,  0.07621995, ..., -0.35139933,
#          0.10296169,  0.19293363],
#        ...,
#        [-0.1453888 ,  0.04595867,  0.04800978, ..., -0.11849089,
#         -0.06036516, -0.16451824],
#        [ 0.03487392, -0.03669805,  0.06545562, ..., -0.05750089,
#          0.05918353, -0.08098674],
#        [-0.09450219,  0.06656731,  0.13598591, ..., -0.04341026,
#         -0.03367222,  0.26572768]])}
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# Wall time: 1.47 s
# Pipeline is done.

# %%
embed_file = os.path.join(output_dir, 'emb-00000-of-00001.tfrecords')
sample = 5

# Create a description of the features.
feature_description = {
    'text': tf.io.FixedLenFeature([], tf.string),
    'embedding': tf.io.FixedLenFeature([projected_dim], tf.float32)
}

def _parse_example(example):
  # Parse the input `tf.Example` proto using the dictionary above.
  return tf.io.parse_single_example(example, feature_description)

dataset = tf.data.TFRecordDataset(embed_file)
for record in dataset.take(sample).map(_parse_example):
  print("{}: {}".format(record['text'].numpy().decode('utf-8'), record['embedding'].numpy()[:10]))
# Out:
# 16岁 男孩 带 妹妹 野泳 溺亡: [-0.44405052  0.3531129   0.26800418 -0.27429968  0.01456182 -0.04958998
#  -0.04472568  0.00554457 -0.03389261  0.04246975]
# 18日 夜间 起 9 省市 部分 地区 有 大 暴雨: [ 0.02551387  0.11336418  0.2438921  -0.22233595  0.12911782 -0.0055292
#   0.14693233  0.25961086 -0.20714208  0.05031455]
# 23名 教师 被 送 东南亚 读 博 ？ 官方 调查: [ 0.08106706  0.19661695  0.17876275  0.1535983   0.1054814   0.0735248
#   0.0520003   0.11827813  0.0022237  -0.06956445]
# 25岁 男子 因 长相 成熟 常 被 误 认为 42岁: [-0.10604525  0.26778027  0.1457244  -0.1274168  -0.12084347 -0.00279967
#   0.02119731  0.27225342  0.30516258 -0.23033373]
# 31 省份 昨 增 本土 117 + 393例: [-0.14986767  0.22266015 -0.06321964  0.09006175  0.08358847 -0.15165737
#  -0.0774148   0.06468168 -0.07511383  0.00076797]

# %%
def build_index(embedding_files_pattern, index_filename, vector_length, 
    metric='angular', num_trees=100):
  '''Builds an ANNOY index'''

  annoy_index = annoy.AnnoyIndex(vector_length, metric=metric)
  # Mapping between the item and its identifier in the index
  mapping = {}

  embed_files = tf.io.gfile.glob(embedding_files_pattern)
  num_files = len(embed_files)
  print('Found {} embedding file(s).'.format(num_files))

  item_counter = 0
  for i, embed_file in enumerate(embed_files):
    print('Loading embeddings in file {} of {}...'.format(i+1, num_files))
    dataset = tf.data.TFRecordDataset(embed_file)
    for record in dataset.map(_parse_example):
      text = record['text'].numpy().decode("utf-8")
      embedding = record['embedding'].numpy()
      mapping[item_counter] = text
      annoy_index.add_item(item_counter, embedding)
      item_counter += 1
      if item_counter % 100000 == 0:
        print('{} items loaded to the index'.format(item_counter))

  print('A total of {} items added to the index'.format(item_counter))

  print('Building the index with {} trees...'.format(num_trees))
  annoy_index.build(n_trees=num_trees)
  print('Index is successfully built.')

  print('Saving index to disk...')
  annoy_index.save(index_filename)
  print('Index is saved to disk.')
  print("Index file size: {} GB".format(
    round(os.path.getsize(index_filename) / float(1024 ** 3), 2)))
  annoy_index.unload()

  print('Saving mapping to disk...')
  with open(index_filename + '.mapping', 'wb') as handle:
    pickle.dump(mapping, handle, protocol=pickle.HIGHEST_PROTOCOL)
  print('Mapping is saved to disk.')
  print("Mapping file size: {} MB".format(
    round(os.path.getsize(index_filename + '.mapping') / float(1024 ** 2), 2)))

# %%
embedding_files = "{}/emb-*.tfrecords".format(output_dir)
embedding_dimension = projected_dim
index_filename = "index"

# !rm {index_filename}
# !rm {index_filename}.mapping

# %time build_index(embedding_files, index_filename, embedding_dimension)
# Out:
# Found 1 embedding file(s).
# Loading embeddings in file 1 of 1...
# A total of 2429 items added to the index
# Building the index with 100 trees...
# Index is successfully built.
# Saving index to disk...
# Index is saved to disk.
# Index file size: 0.0 GB
# Saving mapping to disk...
# Mapping is saved to disk.
# Mapping file size: 0.13 MB
# Wall time: 277 ms

# %%
index = annoy.AnnoyIndex(embedding_dimension)
index.load(index_filename, prefault=True)
print('Annoy index is loaded.')
with open(index_filename + '.mapping', 'rb') as handle:
  mapping = pickle.load(handle)
print('Mapping file is loaded.')
# Out:
# Annoy index is loaded.
# Mapping file is loaded.

# %%
def find_similar_items(embedding, num_matches=5):
  '''Finds similar items to a given embedding in the ANN index'''
  ids = index.get_nns_by_vector(
  embedding, num_matches, search_k=-1, include_distances=False)
  items = [mapping[i] for i in ids]
  return items

# %%
# Load the TF-Hub model
print("Loading the TF-Hub model...")
# %time embed_fn = tf_hub.load(model_url)
print("TF-Hub model is loaded.")

random_projection_matrix = None
if os.path.exists('random_projection_matrix'):
  print("Loading random projection matrix...")
  with open('random_projection_matrix', 'rb') as handle:
    random_projection_matrix = pickle.load(handle)
  print('random projection matrix is loaded.')

def extract_embeddings(query):
  '''Generates the embedding for the query'''
  query_embedding =  embed_fn([query])[0].numpy()
  if random_projection_matrix is not None:
    query_embedding = query_embedding.dot(random_projection_matrix)
  return query_embedding
# Out:
# Loading the TF-Hub model...
# Wall time: 754 ms
# TF-Hub model is loaded.
# Loading random projection matrix...
# random projection matrix is loaded.

# %%
extract_embeddings("手机")
# Out:
# array([-0.11337818,  0.04575574,  0.04463463, -0.10445188, -0.18069048,
#         0.12225582,  0.26330909,  0.01543695,  0.19818887, -0.072975  ,
#        -0.02582843, -0.06593285,  0.00227983, -0.27449116, -0.04524873,
#        -0.03312959, -0.08307707, -0.01929841,  0.05727324, -0.15619984,
#         0.11091063, -0.1101066 , -0.16211552, -0.12401878, -0.07660548,
#         0.02159346, -0.09039252,  0.02480844,  0.0110216 , -0.03137947,
#        -0.0252301 , -0.03765644,  0.08342628,  0.08584248, -0.15852213,
#        -0.18235968,  0.03543031, -0.13331294,  0.19678961,  0.25472635,
#         0.19395137, -0.04133281, -0.17732195, -0.14478255, -0.28942486,
#        -0.26368379, -0.00774473,  0.19081017, -0.12986338, -0.09469636,
#         0.00750706,  0.13470999, -0.10692975,  0.08550254, -0.02688783,
#         0.00403132, -0.08329207, -0.16139398, -0.05221603, -0.12629057,
#         0.03035858, -0.06683127,  0.15506885, -0.1314981 ])

# %%
query = "台湾"

print("Generating embedding for the query...")
# %time query_embedding = extract_embeddings(query)



print("")
print("Finding relevant items in the index...")
# %time items = find_similar_items(query_embedding, 20)

print("")
print("Results:")
print("=========")
for item in items:
  print(item)
# Out:
# Generating embedding for the query...
# Wall time: 999 µs
#
# Finding relevant items in the index...
# Wall time: 1 ms
#
# Results:
# =========
# 中国 大陆 首次 记录 到 笑鸥
# 中国 大陆 首次 记录 到 笑鸥
# 台 专家 批 民进党 挖深 两岸 鸿沟
# 美国 前 国防部长 窜访 台湾
# 中国 内地 两周 现 10种 奥密克戎变异株
# 墨西哥 替代 中国 占 美国 彩电 六成 市场
# 安徽 蚌埠 ： 将 对 5 - 10万 客户 本金 垫付
# 广东 昨 增 本土 23 + 9例   在 深圳 、 中山
# 台湾 台东县 海域 发生 4.7级 地震
# 湖北 通缉 12名 涉 重大 刑案 在逃 人员
# 湖北 通缉 12名 涉 重大 刑案 在逃 人员
# 台湾 渔民 钓 起 玳瑁 石斑   称 50年 首见
# 河北 武安 发现 明朝 万历 年间 圣旨
# 美英 情报 官员 为何 频炒 所谓 大陆 攻 台
# 陆生 恐 成 绝响   台湾 高教 遭 双重 夹击
# LADY M 将 终止 内地 所有 实体 门店
# LADY M 将 终止 内地 所有 实体 门店
# 第五届 数字 中国 建设 成果 展 福州 开展
# 国台办 批 欧洲 议会 副议长 窜访 台湾
# 国台办 批 欧洲 议会 副议长 窜访 台湾
